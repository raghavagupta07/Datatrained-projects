# %%
#import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read the data from csv file to pandas dataframe
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/Advertising.csv')
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# here we have totally 200 rows and 5 columns

# %% [markdown]
# tv , radio , newspaper are the features and sales is our target column

# %%
#printing the first five rows of the data using with .head()
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
#total no.of rows and columns to check below
df.shape
# Out:
# (200, 5)

# %% [markdown]
# 200 rows and 5 columns

# %%
#find some more information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   radio       200 non-null    float64
#  3   newspaper   200 non-null    float64
#  4   sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# here we observed dtype of the columns are float type and no null values

# %%
#check the number of missing values in each column in a df
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %% [markdown]
# no missing values are present in the dataset

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# here counts are equal numbers now check how much pof relationship between the features and the lables

# %% [markdown]
# # EDA

# %%
#visualize the relationship b/w features and weights
fig,axs = plt.subplots(1,3)
df.plot(kind = 'scatter',x = 'TV',y = 'sales',ax = axs[0],figsize=(16,8))
df.plot(kind = 'scatter',x = 'radio',y = 'sales',ax = axs[1])
df.plot(kind = 'scatter',x = 'newspaper',y = 'sales',ax = axs[2])
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='sales'>

# %% [markdown]
# here what we observed in the above three graphs in advertaise on tv increases sales are also increasing and it showing a positive relationship b/w a tv and sales.
# same like in radio also showing a some postive relationship b/w radio and sales, but in newspaper sales showing totaly negative realtionship

# %%
#find correlation
df.corr
# Out:
# <bound method DataFrame.corr of      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]>

# %%
#lets check correlation in pairplot
sns.pairplot(df , diag_kind='kde')

# %%
#lets visualize the correlation between colomns using with heatmap
fig, ax = plt.subplots(figsize=(13,5))
sns.heatmap(df.corr(), annot=True, linewidths=.5, ax=ax, cmap='rainbow')
plt.show()

# %%
#seperate features and target columns from dataframe
x = df[['TV','radio','newspaper']]
y = df['sales']

# %%
x.head()
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %%
#check skew
x.skew
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.skew of         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#check outliers in box plot
fig, axs = plt.subplots(3, figsize = (5,5))
plt1 = sns.boxplot(x['TV'], ax = axs[0])
plt2 = sns.boxplot(x['newspaper'], ax = axs[1])
plt3 = sns.boxplot(x['radio'], ax = axs[2])
plt.tight_layout()

# %% [markdown]
# here we have two outliers are in newspaper

# %%
#remove outliers with power transform
from sklearn.preprocessing import power_transform
x_new=power_transform(x)
x_new=pd.DataFrame(x_new,columns=x.columns)

# %%
x_new.skew()
# Out:
# TV          -0.315199
# radio       -0.242968
# newspaper   -0.077942
# dtype: float64

# %%
#check outliers in box plot
fig, axs = plt.subplots(3, figsize = (5,5))
plt1 = sns.boxplot(x_new['TV'], ax = axs[0])
plt2 = sns.boxplot(x_new['newspaper'], ax = axs[1])
plt3 = sns.boxplot(x_new['radio'], ax = axs[2])
plt.tight_layout()

# %% [markdown]
# outliers are removed but we go before skew data only

# %%
x = df[['TV','radio','newspaper']]
y = df['sales']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split,cross_val_score,cross_val_predict
from sklearn.preprocessing import scale
from sklearn.linear_model import Ridge,Lasso
from sklearn.linear_model import RidgeCV,LassoCV
from sklearn import metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
lm = LinearRegression()
lr = Lasso()
ri = Ridge()
rf = RandomForestRegressor()

# %%
models = LinearRegression(),Ridge(),Lasso(), RandomForestRegressor()

# %%
#split daaframe into train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=28)

# %%
#coefficient matrix
#MAE MSE RMSE Using with metrics 
maelist=[]
mselist=[]
rmselist=[]
r2list=[]
def create_model(model):
    m=model
    m.fit(x_train,y_train)
    p=m.predict(x_test)
    
    mae=mean_absolute_error(p,y_test)
    mse=mean_squared_error(p,y_test)
    rmse=np.sqrt(mean_squared_error(p,y_test))
    r2=r2_score(y_test,p)
    
    maelist.append(mae)
    mselist.append(mse)
    rmselist.append(rmse)
    r2list.append(r2)
    
    print(m)
    print('Mean absolute error',mae)
    print('Mean squared error',mse)
    print('Root Mean squared error',rmse)
    print('R2 Score',r2)
    print('---------------------------------------------------------------------------------------------------------')

# %%
for i in models:
    create_model(i)
# Out:
# LinearRegression()
# Mean absolute error 1.320771787348891
# Mean squared error 2.6274665528028667
# Root Mean squared error 1.620946190594514
# R2 Score 0.912812346071917
# ---------------------------------------------------------------------------------------------------------
# Ridge()
# Mean absolute error 1.320794956963959
# Mean squared error 2.627520581291336
# Root Mean squared error 1.6209628562343235
# R2 Score 0.9128105532357151
# ---------------------------------------------------------------------------------------------------------
# Lasso()
# Mean absolute error 1.3350025445159155
# Mean squared error 2.6618664793849174
# Root Mean squared error 1.631522748656885
# R2 Score 0.9116708476612948
# ---------------------------------------------------------------------------------------------------------
# RandomForestRegressor()
# Mean absolute error 0.5201333333333349
# Mean squared error 0.48453826666666866
# Root Mean squared error 0.6960878297073356
# ...

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
#now check with stats models with best r2score
rf = smf.ols(formula = 'sales ~ TV + radio + newspaper',data = df).fit()
rf.conf_int()
rf.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Fri, 06 Aug 2021   Prob (F-statistic):           1.58e-96
# Time:                        00:55:27   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %% [markdown]
# here what the stats understand actually we dont need all satas say onle we intrest in r-suared,adjusted r-square,P>|t|,
# in this set adj r -squared giving me 0.896 this my model conference and how much my model ability to understand my data
# and tv and radio reject null-hypothesis because in this p value show 0.000 it means p value is less than alpha(o.05 is the p-value)
# and newspaer 0.860 which is not less tha alpha value so null hypothsis says their is no relation b/w newspaper and sales and we failed to reject null hypothesis ,
# so unecessary to invest advertaisment in newspaper.

# %%
#Checking the R-squared on the test set 
r_squared = r2_score(y_test, y_pred)
r_squared
# Out:
# 0.9116708476612948

# %%
print('Minimum Mean Absolute error is shown by ',models[maelist.index(min(maelist))],min(maelist))
print('Minimum Mean squared error is shown by ',models[mselist.index(min(mselist))],min(mselist))
print('Minimum Root Mean squared error is shown by ',models[rmselist.index(min(rmselist))],min(rmselist))
print('Maximun R2 Score is shown by ',models[r2list.index(max(r2list))],max(r2list))
# Out:
# Minimum Mean Absolute error is shown by  RandomForestRegressor() 0.5201333333333349
# Minimum Mean squared error is shown by  RandomForestRegressor() 0.48453826666666866
# Minimum Root Mean squared error is shown by  RandomForestRegressor() 0.6960878297073356
# Maximun R2 Score is shown by  RandomForestRegressor() 0.9839214871588067

# %% [markdown]
# RandomForestRegressor() is the best r2 score in regression model now i go with hyperperameter tuning

# %%
#residuals
#visualize the fit on the test set
test_residuals=y_test - y_pred
sns.scatterplot(x=y_test , y=y_pred)
plt.xlabel('y_test')
plt.ylabel('y_pred')
# Out:
# Text(0, 0.5, 'y_pred')

# %% [markdown]
# here we observed it showing a positive relationship and residuals also close to predicted ponts only,and here relation our test and predected vaukes showing best fit line and positive correlation.

# %% [markdown]
# # Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV
from scipy.stats import randint

# %%
model=RandomForestRegressor()
param_grid={ 
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }
regression=GridSearchCV(model,param_grid,cv=10)

# %%
regression.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestRegressor(),
#              param_grid={'bootstrap': [True, False],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [2, 4, 8],
#                          'n_estimators': [10, 20, 30]})

# %%
rf=regression.best_estimator_
print(rf)
# Out:
# RandomForestRegressor(min_samples_split=4, n_estimators=30)

# %%
rf=regression.best_params_
print(rf)
# Out:
# {'bootstrap': True, 'max_features': 'auto', 'min_samples_split': 4, 'n_estimators': 30}

# %%
rf=regression.best_score_
print(rf)
# Out:
# 0.9629594645611672

# %%
rf=regression.predict(x_test)

# %%
mae=mean_absolute_error(rf,y_test)
mse=mean_squared_error(rf,y_test)
rmse=np.sqrt(mean_squared_error(rf,y_test))
r2=r2_score(y_test,rf)

# %%
print('Mean absolute error',mae)
print('Mean squared error',mse)
print('Root Mean squared error',rmse)
print('R2 Score',r2)
# Out:
# Mean absolute error 0.5727193342151672
# Mean squared error 0.5570985667240838
# Root Mean squared error 0.7463903581398167
# R2 Score 0.9815137068110131

# %% [markdown]
# RandomForestRegression after Hypertuning gives best nearly same result as shown above, so RandomForestRegression is good and best accuracy model.
