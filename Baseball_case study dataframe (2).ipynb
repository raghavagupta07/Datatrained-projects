# %%
#importing necessary libraries
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#read csv file convert into dataframe 
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
#take top five data in dataframe using with head function
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
#check how many rows and columns in a dataframe
df.shape
# Out:
# (30, 17)

# %% [markdown]
# total we have 30 rows and 17 columns

# %%
#find some more information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# information of data tells here no null values present,all columns are integer data type except ERA column it is float data type and also tells data shape also total 17 columns and 30 rows

# %%
sum(df.duplicated())
# Out:
# 0

# %% [markdown]
# there are no duplicate values are present

# %%
#check the number of missing values in each column in a df
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# there are no null values are present

# %% [markdown]
# we can use heatmap also to checl null values it is good to see in visualization lets do heatmap

# %%
#heatmap to check null values
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# there no null values

# %%
#understand data at high level .check the statistics of the dataframe
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# here so many things we can find in this describe function,first thing we can understand here rows in count showing all are 30 rows that means here absorved there is no missing values here are present.
# here mean is their some values im not do any inerpretation here i will make interpretationm when i will see standard deviation find is their any wrong here,
# std is lessthan mean ya it looks ok good no worry about, if it mean and std is to very close each other or equal ya start worring and in trouble.
# here min to max deviation nornmally distribution lets see in some visualization by graphs

# %% [markdown]
# # EDA

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
#how data distributed every column by visualization
plt.figure(figsize = (20,23))
plotnumber = 1

for column in df:
    if plotnumber<=18:
        ax = plt.subplot(3,6,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize = 20)
               
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# The data distribution is normally distributed and there dosn't seem to be any skewness
#
# and lets check relationship between features and target

# %%
#lets check which column is the highest numbers
df.plot.line(figsize=(10,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# AB column is the highest number in the dataset remaining all below around 1500 numbers

# %%
df.plot.line(subplots = True, figsize=(20,20))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>], dtype=object)

# %% [markdown]
# here coulms are shows in how much range

# %%
#visualizing with bar plot letsee how it looks
df.plot.bar(subplots= True,stacked= False, figsize=(20,30))
# Out:
# array([<AxesSubplot:title={'center':'W'}>,
#        <AxesSubplot:title={'center':'R'}>,
#        <AxesSubplot:title={'center':'AB'}>,
#        <AxesSubplot:title={'center':'H'}>,
#        <AxesSubplot:title={'center':'2B'}>,
#        <AxesSubplot:title={'center':'3B'}>,
#        <AxesSubplot:title={'center':'HR'}>,
#        <AxesSubplot:title={'center':'BB'}>,
#        <AxesSubplot:title={'center':'SO'}>,
#        <AxesSubplot:title={'center':'SB'}>,
#        <AxesSubplot:title={'center':'RA'}>,
#        <AxesSubplot:title={'center':'ER'}>,
#        <AxesSubplot:title={'center':'ERA'}>,
#        <AxesSubplot:title={'center':'CG'}>,
#        <AxesSubplot:title={'center':'SHO'}>,
#        <AxesSubplot:title={'center':'SV'}>,
#        <AxesSubplot:title={'center':'E'}>], dtype=object)

# %% [markdown]
#  plotting a histogram of the target column so we can see the distribution of wins.

# %%
#####Now let’s visualize the count of rings using Seaborn
count = df["W"].value_counts()
plt.figsize = (50,40)
plt.ylabel("Count",fontsize = 20)
plt.xlabel("W",fontsize = 20)
sns.barplot(count.index, count.values)
plt.show()

# %%
#Let’s look at the correlation between the variables
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
#lets check correlation in pairplot
sns.pairplot(df , diag_kind='kde')

# %%
#heat map
fig, ax = plt.subplots(figsize=(17,13))
sns.heatmap(df.corr(), annot=True, linewidths=.5, ax=ax)
plt.show()

# %% [markdown]
# RA ,ER,ERA is highly negative correlated with target class.

# %%
#visualize correlation 
plt.figure(figsize=(22,7))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='c')
plt.xlabel('feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# here almost features are correlation

# %%
Y = df['W']
X = df.drop(columns = ['W'])

# %%
#visulizing relationship
plt.figure(figsize = (20,10))
plotnumber = 1

for column in X:
    if plotnumber<=18:
        ax = plt.subplot(3,6,plotnumber)
        plt.scatter(X[column],Y)
        plt.xlabel(column,fontsize = 20)
        plt.ylabel('W',fontsize = 20)
               
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# the relationship between fautures and labels are alsmost looks linear realtion

# %% [markdown]
# but here RA,ER and ERA are not in relation

# %% [markdown]
# # Bivariant Analysis

# %%
plt.scatter(df.R,df.W)
plt.xlabel("Runs")
plt.ylabel("WINS")
plt.show()

# %%
# runs relation with dataset 

for i in df.columns:
    plt.figure(figsize = (20,10))
    sns.barplot(x=df[i],y=df.W)

# %% [markdown]
# Relationship between feature and label variable observed

# %%
df.hist(bins=5, figsize=(15,15));

# %% [markdown]
# this histogram tells normally diostributed and it is Bivariante analysis there are some skewness is present

# %% [markdown]
# # Check Outliers

# %%
#create the box plot
fig,ax = plt.subplots(ncols=6,nrows=3,figsize=(20,30))
index=0
ax = ax.flatten()

for col, value in df.items():
    if col !='type':
        sns.boxplot(y=col,data=df,ax=ax[index])
        index+= 1

# %% [markdown]
# outliers present in R , SHO , E columns

# %%
from scipy.stats import zscore
z=zscore(df)
z
# Out:
# array([[ 1.36540860e+00,  6.19077968e-01,  8.47731264e-01,
#          1.66368512e+00,  1.42017307e+00,  1.04119304e+00,
#         -7.87298598e-01, -1.53490242e+00, -2.69762957e+00,
#          9.13883291e-01, -6.66233927e-01, -5.05110079e-01,
#         -5.06955186e-01, -5.39806195e-01, -8.14628593e-01,
#          1.67160651e+00, -4.61469635e-01],
#        [ 1.97838300e-01,  1.34431656e-01, -7.11093535e-01,
#         -9.70680764e-01,  1.27403389e-01,  1.23580856e+00,
#         -2.43966683e-01, -5.36591904e-01,  1.54878442e-01,
#         -6.01825582e-01,  1.65970766e-01,  2.48929848e-01,
#          2.54597523e-01, -5.39806195e-01,  1.72800005e-01,
#          2.49879323e-01, -6.07196888e-01],
#        [ 3.24325082e-03, -3.32905860e-01, -1.11523330e+00,
#         -1.51891367e-01,  1.58879521e+00, -2.23807850e-01,
#         -7.23377196e-01,  1.13914361e+00, -8.93981893e-01,
#          1.11449182e-01, -6.80339091e-01, -7.51623132e-01,
# ...

# %%
X = df[(z < 3).all(axis=1)]

# %%
X.shape
# Out:
# (29, 17)

# %%
# Data loss

(30-29)/30*100
# Out:
# 3.3333333333333335

# %% [markdown]
# # checking for Skewness

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
# new data after removing the outliers 
X.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
from sklearn.preprocessing import power_transform 
df_New=power_transform(X)
df_New=pd.DataFrame(df_New,columns=X.columns)

# %%
df_New.skew()
# Out:
# W     -0.015560
# R     -0.024842
# AB     0.000000
# H      0.000000
# 2B    -0.052793
# 3B    -0.075139
# HR     0.000448
# BB    -0.008572
# SO     0.051530
# SB    -0.009570
# RA    -0.011974
# ER    -0.004988
# ERA   -0.000401
# CG    -0.045947
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %% [markdown]
# # perform EDA is the best possible way using pandas profile

# %%
# we can also to create the simple report of EDA quikly and easily
profile = ProfileReport(df,title = 'Pandas Profile Report',explorative = True)

# %%
profile.to_widgets()
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %% [markdown]
# wow perform EDA is the best possible way using pandas profile and it will show all the eda in one table format correlation visulize with heatmap and variables,missing values,linear relationship etc it will show in a minutes

# %%
#Standardize features by removing the mean and scaling to unit variance
scaler = StandardScaler()

new_df= pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %%
new_df.head()
# Out:
#           W         R        AB         H        2B        3B        HR  \
# 0  1.416025  0.959398  0.830084  1.738306  1.556538  1.010845 -0.765863
# 1  0.239947  0.331147 -0.702831 -0.938698  0.201171  1.208917 -0.181389
# 2  0.043934 -0.274666 -1.100253 -0.106656  1.733325 -0.276617 -0.697101
# 3 -0.446099 -1.329231  0.233951 -0.359886 -0.800621 -0.474688 -0.869006
# 4 -0.642112  0.174084  1.255894  2.063888  0.908319  1.704094 -0.353293
#
#          BB        SO        SB        RA        ER       ERA        CG  \
# 0 -1.536359 -2.727623  0.905953 -0.664514 -0.511148 -0.511388 -0.501486
# 1 -0.495021  0.121896 -0.585315  0.154638  0.232161  0.238952 -0.501486
# 2  1.252941 -0.925866  0.116458 -0.678397 -0.754153 -0.643801  2.854612
# 3 -1.145857 -0.201246 -0.673037  0.168522  0.089217  0.040333  1.363013
# 4 -0.197495  0.072935 -0.015124  1.584683  1.561540  1.496876  1.363013
#
#         SHO        SV         E
# 0 -0.813262  1.643157 -0.471091
# 1  0.159299  0.211006 -0.614898
# ...

# %%
#Spliting the data

x=new_df.drop('W',axis=1)
y=new_df['W']

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split,cross_val_score,cross_val_predict,GridSearchCV
from sklearn.preprocessing import scale
from sklearn.linear_model import Ridge,Lasso
from sklearn.linear_model import RidgeCV,LassoCV
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
#train test split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=50)

# %%
#check the shape of train test split
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((23, 16), (6, 16), (23,), (6,))

# %%
lm = LinearRegression()
kn = KNeighborsRegressor()
ab = AdaBoostRegressor()
lr = Lasso()
ri = Ridge()
rf = RandomForestRegressor()
xgb = XGBRegressor()

# %%
models = LinearRegression(),Ridge(),Lasso(), RandomForestRegressor(),XGBRegressor(), KNeighborsRegressor(),AdaBoostRegressor()

# %%
#coefficient matrix
#MAE MSE RMSE Using with metrics 
maelist=[]
mselist=[]
rmselist=[]
r2list=[]
def create_model(model):
    m=model
    m.fit(x_train,y_train)
    p=m.predict(x_test)
    
    mae=mean_absolute_error(p,y_test)
    mse=mean_squared_error(p,y_test)
    rmse=np.sqrt(mean_squared_error(p,y_test))
    r2=r2_score(y_test,p)
    
    maelist.append(mae)
    mselist.append(mse)
    rmselist.append(rmse)
    r2list.append(r2)
    
    print(m)
    print('Mean absolute error',mae)
    print('Mean squared error',mse)
    print('Root Mean squared error',rmse)
    print('R2 Score',r2)
    print('---------------------------------------------------------------------------------------------------------')

# %%
for i in models:
    create_model(i)
# Out:
# LinearRegression()
# Mean absolute error 0.27858913849185346
# Mean squared error 0.09751711188545727
# Root Mean squared error 0.3122772996640282
# R2 Score 0.8402586950388152
# ---------------------------------------------------------------------------------------------------------
# Ridge()
# Mean absolute error 0.1817895413150663
# Mean squared error 0.0652669837825277
# Root Mean squared error 0.2554740373942677
# R2 Score 0.8930871417464911
# ---------------------------------------------------------------------------------------------------------
# Lasso()
# Mean absolute error 1.073810747445124
# Mean squared error 1.4061356947234749
# Root Mean squared error 1.1858059262474088
# R2 Score -1.3033695982656286
# ---------------------------------------------------------------------------------------------------------
# RandomForestRegressor()
# Mean absolute error 0.5127375299821137
# Mean squared error 0.42424846098496943
# Root Mean squared error 0.6513435813646815
# ...

# %% [markdown]
# # Cross Validation

# %%
#do cross validation for score
print(cross_val_score(lr,x,y,cv=5).mean())
# Out:
# -0.3862685306927355

# %%
print(cross_val_score(kn,x,y,cv=5).mean())
# Out:
# 0.0398480673472857

# %%
print(cross_val_score(lm,x,y,cv=5).mean())
# Out:
# 0.037628660496315545

# %%
print(cross_val_score(ab,x,y,cv=5).mean())
# Out:
# -0.6876958614920397

# %%
print(cross_val_score(xgb,x,y,cv=5).mean())
# Out:
# -1.273117604681841

# %%
print(cross_val_score(rf,x,y,cv=5).mean())
# Out:
# -0.7170061218635142

# %%
print(cross_val_score(ri,x,y,cv=5).mean())
# Out:
# 0.3374778769069564

# %%
print('Minimum Mean Absolute error is shown by ',models[maelist.index(min(maelist))],min(maelist))
print('Minimum Mean squared error is shown by ',models[mselist.index(min(mselist))],min(mselist))
print('Minimum Root Mean squared error is shown by ',models[rmselist.index(min(rmselist))],min(rmselist))
print('Maximun R2 Score is shown by ',models[r2list.index(max(r2list))],max(r2list))
# Out:
# Minimum Mean Absolute error is shown by  Ridge() 0.1817895413150663
# Minimum Mean squared error is shown by  Ridge() 0.0652669837825277
# Minimum Root Mean squared error is shown by  Ridge() 0.2554740373942677
# Maximun R2 Score is shown by  Ridge() 0.8930871417464911

# %% [markdown]
# Difference between R2 score and cross validation score is least in Ridge regression model, hence we'll work on Ridge Model.

# %% [markdown]
# # Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV
from scipy.stats import randint

# %%
parameters={'alpha':[0.1,0.01,0.001,0.0001],
       'solver':['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']
           }

# %%
model=Ridge()

# %%
grid_search=GridSearchCV(Ridge(),parameters,cv=5)

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 0.01, 0.001, 0.0001],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr',
#                                     'sparse_cg', 'sag', 'saga']})

# %%
grid_search.best_params_
# Out:
# {'alpha': 0.1, 'solver': 'saga'}

# %%
# Ridge model
ri =Ridge(alpha=0.1,solver ='saga')
ri.fit(x_train,y_train)
ri.score(x_train,y_train)
predict = ri.predict(x_test)

print(r2_score(y_test,predict))
# Out:
# 0.9177803533274596

# %%
print(cross_val_score(ri,x,y,cv=5).mean())
# Out:
# 0.31152459723035647

# %% [markdown]
# my ridge regression is improved after hyper paramerter tuning

# %% [markdown]
# Ridge Regrssion model is giving higher accuracy so we are selecting this model.

# %% [markdown]
# ### Check RidgeCV

# %%
#Ridgecv
ridge_cv = RidgeCV(alphas = np.arange(0.001,0.1,0.01),normalize = True)
ridge_cv.fit(x_train,y_train)
# Out:
# RidgeCV(alphas=array([0.001, 0.011, 0.021, 0.031, 0.041, 0.051, 0.061, 0.071, 0.081,
#        0.091]),
#         normalize=True)

# %%
ridge_cv.alpha_
# Out:
# 0.09099999999999998

# %%
ridge_model = Ridge(alpha = ridge_cv.alpha_)
ridge_model.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.09099999999999998)

# %%
ridge_model.score(x_test,y_test)
# Out:
# 0.9117098791885019

# %% [markdown]
# after gridsearch_cv and ridge_cv also i got 91% accuracy i cleared all the overfit with cross validation tecniques im considering ridge as a best accuracy model

# %% [markdown]
# # Saving Model

# %%
import joblib
joblib.dump(ri,"Baseball_wins_predict")
# Out:
# ['Baseball_wins_predict']
