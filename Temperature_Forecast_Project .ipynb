# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Dataset2/main/temperature.csv')
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# 1       90.604721         29.850689         24.035009   5.691890   51.937448
# 2       83.973587         30.091292         24.565633   6.138224   20.573050
# 3       96.483688         29.704629         23.326177   5.650050   65.727144
# 4       90.155128         29.113934         23.486480   5.735004  107.965535
# ...           ...               ...               ...        ...         ...
# 7747    78.869858         26.352081         18.775678   6.148918   72.058294
# 7748    77.294975         27.010193         18.733519   6.542819   47.241457
# 7749    77.243744         27.939516         18.522965   7.289264    9.090034
# 7750    58.936283         17.624954         14.272646   2.882580  -13.603212
# 7751   100.000153         38.542255         29.619342  21.857621  213.414006
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# 0     ...    0.000000    0.000000    0.000000  37.6046  126.991  212.3350
# 1     ...    0.000000    0.000000    0.000000  37.6046  127.032   44.7624
# 2     ...    0.000000    0.000000    0.000000  37.5776  127.058   33.3068
# 3     ...    0.000000    0.000000    0.000000  37.6450  127.022   45.7160
# 4     ...    0.000000    0.000000    0.000000  37.5507  127.135   35.0380
# ...   ...         ...         ...         ...      ...      ...       ...
# 7747  ...    0.000000    0.000000    0.000000  37.5372  126.891   15.5876
# 7748  ...    0.000000    0.000000    0.000000  37.5237  126.909   17.2956
# 7749  ...    0.000000    0.000000    0.000000  37.5237  126.970   19.5844
# 7750  ...    0.000000    0.000000    0.000000  37.4562  126.826   12.3700
# 7751  ...   21.621661   15.841235   16.655469  37.6450  127.135  212.3350
#
#          Slope  Solar radiation  Next_Tmax  Next_Tmin
# 0     2.785000      5992.895996       29.1       21.2
# 1     0.514100      5869.312500       30.5       22.5
# 2     0.266100      5863.555664       31.1       23.9
# 3     2.534800      5856.964844       31.7       24.3
# 4     0.505500      5859.552246       31.2       22.5
# ...        ...              ...        ...        ...
# 7747  0.155400      4443.313965       28.3       18.1
# 7748  0.222300      4438.373535       28.6       18.8
# 7749  0.271300      4451.345215       27.8       17.4
# 7750  0.098475      4329.520508       17.4       11.3
# 7751  5.178230      5992.895996       38.9       29.8
#
# [7752 rows x 25 columns]

# %% [markdown]
# Total we have 7752 rows and 25 columns in a dataset

# %% [markdown]
# call first five records from dataset

# %%
#calling fiest five records
df.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
#    LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM   Slope  \
# 0         0.0         0.0  37.6046  126.991  212.3350  2.7850
# 1         0.0         0.0  37.6046  127.032   44.7624  0.5141
# 2         0.0         0.0  37.5776  127.058   33.3068  0.2661
# 3         0.0         0.0  37.6450  127.022   45.7160  2.5348
# 4         0.0         0.0  37.5507  127.135   35.0380  0.5055
#
#    Solar radiation  Next_Tmax  Next_Tmin
# 0      5992.895996       29.1       21.2
# 1      5869.312500       30.5       22.5
# 2      5863.555664       31.1       23.9
# 3      5856.964844       31.7       24.3
# 4      5859.552246       31.2       22.5
#
# [5 rows x 25 columns]

# %%
#shape of the dataset
df.shape
# Out:
# (7752, 25)

# %% [markdown]
# see we have 7752 rows and 25 columns

# %%
#understand data at high level .check the statistics of the dataframe
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7750.000000   7682.000000   7682.000000  7677.000000  7677.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.211568      2.969999      2.413961    14.668111     7.192004
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    45.963543    84.222862
# 50%      13.000000     29.900000     23.400000    55.039024    89.793480
# 75%      19.000000     32.000000     24.900000    67.190056    93.743629
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7677.000000       7677.000000  7677.000000  7677.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.947191          2.345347     2.183836    33.730589
# min           17.624954         14.272646     2.882580   -13.603212
# 25%           27.673499         22.089739     5.678705    37.266753
# 50%           29.703426         23.760199     6.547470    56.865482
# 75%           31.710450         25.152909     8.032276    84.223616
# max           38.542255         29.619342    21.857621   213.414006
#
#          LDAPS_CC1  ...   LDAPS_PPT2   LDAPS_PPT3   LDAPS_PPT4          lat  \
# count  7677.000000  ...  7677.000000  7677.000000  7677.000000  7752.000000
# mean      0.368774  ...     0.485003     0.278200     0.269407    37.544722
# std       0.262458  ...     1.762807     1.161809     1.206214     0.050352
# min       0.000000  ...     0.000000     0.000000     0.000000    37.456200
# 25%       0.146654  ...     0.000000     0.000000     0.000000    37.510200
# 50%       0.315697  ...     0.000000     0.000000     0.000000    37.550700
# 75%       0.575489  ...     0.018364     0.007896     0.000041    37.577600
# max       0.967277  ...    21.621661    15.841235    16.655469    37.645000
#
#                lon          DEM        Slope  Solar radiation    Next_Tmax  \
# count  7752.000000  7752.000000  7752.000000      7752.000000  7725.000000
# mean    126.991397    61.867972     1.257048      5341.502803    30.274887
# std       0.079435    54.279780     1.370444       429.158867     3.128010
# min     126.826000    12.370000     0.098475      4329.520508    17.400000
# 25%     126.937000    28.700000     0.271300      4999.018555    28.200000
# 50%     126.995000    45.716000     0.618000      5436.345215    30.500000
# 75%     127.042000    59.832400     1.767800      5728.316406    32.600000
# max     127.135000   212.335000     5.178230      5992.895996    38.900000
#
#          Next_Tmin
# count  7725.000000
# mean     22.932220
# std       2.487613
# min      11.300000
# 25%      21.300000
# 50%      23.100000
# 75%      24.600000
# max      29.800000
#
# [8 rows x 24 columns]

# %% [markdown]
# here counting are in not euqal that means there some null values to find and treat in a datset
# This describes the detailed summary of each and every numerical column which gives the count of the data's, mean, standard-deviation, minimum, maxmium, and quantile range of values.

# %%
#let see ditributiobn of the dataset
#how data distributed every column by histogram
df.hist(bins = 20, figsize = (20,20))
plt.show()

# %% [markdown]
# target variables looks normal and have mild skewness,LDAPS_RHmax has left skewed data,LDAPS_PPT1 to LDAPS_PPT4 has skewed more in right as most of the values are 0 in this as per plot Solar radiation has left skewed and LDAPS_CC1 - LDAPS_CC4 has skewness in right side.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
#  16  LDAPS_PPT3        7677 non-null   float64
#  17  LDAPS_PPT4        7677 non-null   float64
#  18  lat               7752 non-null   float64
#  19  lon               7752 non-null   float64
#  20  DEM               7752 non-null   float64
#  21  Slope             7752 non-null   float64
#  22  Solar radiation   7752 non-null   float64
#  23  Next_Tmax         7725 non-null   float64
#  24  Next_Tmin         7725 non-null   float64
# dtypes: float64(24), object(1)
# memory usage: 1.5+ MB

# %% [markdown]
# here information of the data tells all are in integer dtypes except date column,there are some treat null value shere and also data shape is here 7752rows and 25 columns

# %%
#check_null values in a datset
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %% [markdown]
# We will check for target variables on data distribution,

# %%
df['Next_Tmax'].value_counts()
# Out:
# 29.3    113
# 33.0    106
# 31.3    104
# 29.6    101
# 31.2     98
#        ...
# 20.9      1
# 18.9      1
# 18.6      1
# 37.4      1
# 19.7      1
# Name: Next_Tmax, Length: 183, dtype: int64

# %%
#let’s visualize the count of Next_Tmaxt using plot
df['Next_Tmax'].value_counts().plot.line()
# Out:
# <AxesSubplot:>

# %% [markdown]
# most of the places in seoul has next day maxmium air temperature has (25-30)C to (30-35)C

# %%
df['Next_Tmin'].value_counts()
# Out:
# 23.5    159
# 23.4    157
# 24.0    156
# 23.2    150
# 23.8    149
#        ...
# 13.6      1
# 12.9      1
# 28.2      1
# 29.5      1
# 13.4      1
# Name: Next_Tmin, Length: 157, dtype: int64

# %%
df['Next_Tmin'].value_counts().plot.line()
# Out:
# <AxesSubplot:>

# %% [markdown]
#  the maximum air temperature for the present day is high of 27.5C to 32.5C

# %%
df['Present_Tmin'].value_counts()
# Out:
# 24.0    161
# 23.8    153
# 23.1    144
# 23.5    143
# 23.3    142
#        ...
# 29.6      1
# 13.5      1
# 14.3      1
# 14.2      1
# 29.7      1
# Name: Present_Tmin, Length: 155, dtype: int64

# %%
df['Present_Tmin'].value_counts().plot.line()
# Out:
# <AxesSubplot:>

# %% [markdown]
# the minimum air temperature for the present day range is 22.5C to 25C

# %%
df['LDAPS_RHmin'].value_counts()
# Out:
# 19.794666    2
# 77.030350    2
# 51.810596    2
# 71.658089    2
# 98.524734    2
#             ..
# 84.769783    1
# 76.279388    1
# 88.419456    1
# 55.934109    1
# 56.417843    1
# Name: LDAPS_RHmin, Length: 7672, dtype: int64

# %%
df['LDAPS_RHmin'].value_counts().plot.line()
# Out:
# <AxesSubplot:>

# %% [markdown]
# line plot explains that relative humidity as per LDAPS model states that minimum humidity levels in south korea in summer is of 19% to 98% and we can see the sudden increase from 58% indicates that more places on south korea has humidity of >50%.

# %%
df['LDAPS_RHmax'].value_counts()
# Out:
# 88.938194    2
# 96.058418    2
# 99.251968    2
# 96.525200    2
# 91.776146    2
#             ..
# 92.350754    1
# 90.046745    1
# 95.512535    1
# 84.353996    1
# 92.446472    1
# Name: LDAPS_RHmax, Length: 7664, dtype: int64

# %%
df['LDAPS_RHmax'].value_counts().plot.line()
# Out:
# <AxesSubplot:>

# %% [markdown]
# plot explains about relative humidity in south korea in summer where the maximum humidity ranges from 60% to 100% and the sudden increase from 90% shows that most of the places has maximum of >90% humidity.

# %%
df['LDAPS_Tmax_lapse'].value_counts()
# Out:
# 17.624954    2
# 38.542255    2
# 33.013122    1
# 27.101243    1
# 29.760032    1
#             ..
# 30.491629    1
# 26.700805    1
# 24.515795    1
# 25.898477    1
# 29.100858    1
# Name: LDAPS_Tmax_lapse, Length: 7675, dtype: int64

# %%
df['LDAPS_Tmax_lapse'].value_counts().plot.line()
# Out:
# <AxesSubplot:>

# %%
df['LDAPS_Tmin_lapse'].value_counts()
# Out:
# 29.619342    2
# 14.272646    2
# 25.532282    1
# 26.266966    1
# 23.353502    1
#             ..
# 21.470301    1
# 24.405281    1
# 22.171742    1
# 24.652324    1
# 22.554425    1
# Name: LDAPS_Tmin_lapse, Length: 7675, dtype: int64

# %%
df['LDAPS_Tmin_lapse'].value_counts().plot.line()
# Out:
# <AxesSubplot:>

# %% [markdown]
# varying from place to place and few places has seen the increase maximum lapse rate of 38C and less of 17C and increase minimum lapse rate of 29C and less of 14C.

# %%
df['LDAPS_WS'].value_counts()
# Out:
# 2.882580     2
# 21.857621    2
# 5.345576     1
# 6.349147     1
# 16.002083    1
#             ..
# 7.769172     1
# 5.507503     1
# 5.109735     1
# 5.471099     1
# 5.009154     1
# Name: LDAPS_WS, Length: 7675, dtype: int64

# %%
df['LDAPS_WS'].value_counts().plot.line()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Wind speed is varying gradually from place to place and depends on several factors but can see high of 21m/s and less of 2m/s.

# %%
df['LDAPS_LH'].value_counts()
# Out:
#  213.414006    2
# -13.603212     2
#  77.255976     1
#  104.307979    1
#  65.769970     1
#               ..
#  93.400343     1
#  88.652249     1
#  86.713884     1
#  111.206770    1
#  24.522529     1
# Name: LDAPS_LH, Length: 7675, dtype: int64

# %%
df['LDAPS_LH'].value_counts().plot.line()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Heat flux ranges from <0W/m2 to >200wm2 and we can see some places has heat fluz of >200wm2 as well in south korea.

# %%
df['LDAPS_CC1'].value_counts()
# Out:
# 0.000000    108
# 0.967277      2
# 0.879500      1
# 0.267451      1
# 0.490767      1
#            ...
# 0.369984      1
# 0.792438      1
# 0.288363      1
# 0.605690      1
# 0.012819      1
# Name: LDAPS_CC1, Length: 7569, dtype: int64

# %%
df['LDAPS_CC1'].value_counts().plot.line()
# Out:
# <AxesSubplot:>

# %%
df['LDAPS_CC2'].value_counts()
# Out:
# 0.000000    95
# 0.968353     2
# 0.006605     1
# 0.922053     1
# 0.077009     1
#             ..
# 0.017646     1
# 0.025537     1
# 0.278383     1
# 0.377259     1
# 0.092348     1
# Name: LDAPS_CC2, Length: 7582, dtype: int64

# %%
df['LDAPS_CC2'].value_counts().plot.line()
# Out:
# <AxesSubplot:>

# %%
df['LDAPS_CC3'].value_counts()
# Out:
# 0.000000e+00    76
# 5.810000e-07     2
# 9.837888e-01     2
# 8.680560e-04     2
# 5.150274e-02     1
#                 ..
# 4.378571e-01     1
# 8.118274e-02     1
# 2.568394e-01     1
# 3.273348e-01     1
# 4.907551e-01     1
# Name: LDAPS_CC3, Length: 7599, dtype: int64

# %%
df['LDAPS_CC3'].value_counts().plot.line()
# Out:
# <AxesSubplot:>

# %%
df['LDAPS_CC4'].value_counts()
# Out:
# 0.000000    137
# 0.002604      7
# 0.005208      3
# 0.001736      3
# 0.000070      2
#            ...
# 0.138587      1
# 0.188345      1
# 0.811649      1
# 0.302367      1
# 0.241679      1
# Name: LDAPS_CC4, Length: 7524, dtype: int64

# %%
df['LDAPS_CC4'].value_counts().plot.line()
# Out:
# <AxesSubplot:>

# %% [markdown]
# above all 4 graphs indicates the next day average cloud cover.
#
# cc1 - first 6 hour --> most of the cloud cover % is 0 only and can see max of >90% as well.
# cc2 - second 6 hour --> most of the cloud cover % is 0 and can see max of 97%.
# cc3 - third 6 hour --> most have % of 0 and can see max of >.5 to <.9%
# cc4 - last 6 hour -->. most have % of 0.

# %%
df['LDAPS_PPT1'].value_counts()
# Out:
# 0.000000     4844
# 0.001953       11
# 0.002604        5
# 0.001734        3
# 23.701544       2
#              ...
# 12.410761       1
# 1.220734        1
# 0.007332        1
# 0.009543        1
# 0.038950        1
# Name: LDAPS_PPT1, Length: 2812, dtype: int64

# %%
df['LDAPS_PPT1'].value_counts().plot.line()
# Out:
# <AxesSubplot:>

# %%
df['LDAPS_PPT2'].value_counts()
# Out:
# 0.000000    5151
# 0.001953       7
# 0.000781       3
# 0.000040       3
# 0.001704       2
#             ...
# 0.289520       1
# 0.000682       1
# 0.000100       1
# 0.062325       1
# 0.000575       1
# Name: LDAPS_PPT2, Length: 2510, dtype: int64

# %%
df['LDAPS_PPT2'].value_counts().plot.line()
# Out:
# <AxesSubplot:>

# %%
df['LDAPS_PPT3'].value_counts()
# Out:
# 0.000000    5294
# 0.001953      10
# 0.000852       4
# 0.002604       3
# 0.000558       2
#             ...
# 0.023568       1
# 0.009162       1
# 0.006390       1
# 0.003127       1
# 0.000350       1
# Name: LDAPS_PPT3, Length: 2356, dtype: int64

# %%
df['LDAPS_PPT3'].value_counts().plot.line()
# Out:
# <AxesSubplot:>

# %%
df['LDAPS_PPT4'].value_counts()
# Out:
# 0.000000    5751
# 0.001953       3
# 0.001065       2
# 0.001105       2
# 0.000710       2
#             ...
# 3.670776       1
# 7.328585       1
# 0.228660       1
# 0.577437       1
# 0.076488       1
# Name: LDAPS_PPT4, Length: 1918, dtype: int64

# %%
df['LDAPS_PPT4'].value_counts().plot.line()
# Out:
# <AxesSubplot:>

# %% [markdown]
# he same goes for average percipitation where it is splitted for 6 hours * 4 like cloud cover.
#
# ppt1 --> ranges lies from 0 - 24% and most station has 0%
#
# ppt2 --> range from 0 - 20%
#
# ppt3 --> range from 0 - 16%
#
# ppt4 --> range from 0 -17%

# %%
df['lat'].value_counts()
# Out:
# 37.5507    1240
# 37.5776    1240
# 37.6046     620
# 37.4967     620
# 37.5372     620
# 37.4697     620
# 37.5102     620
# 37.5237     620
# 37.6181     620
# 37.6450     311
# 37.4562     311
# 37.4832     310
# Name: lat, dtype: int64

# %%
sns.countplot(df['lat'])
plt.xticks(rotation = 90)
plt.tight_layout()

# %%
sns.countplot(df['lon'])
plt.xticks(rotation = 90)
plt.tight_layout()

# %% [markdown]
# Latitude and Longtitude explains the station place co-ordinates in South Korea.

# %%
df['DEM'].value_counts()
# Out:
# 212.3350    311
# 12.3700     311
# 30.0464     310
# 82.2912     310
# 15.5876     310
# 45.7160     310
# 17.2956     310
# 52.5180     310
# 208.5070    310
# 54.6384     310
# 59.8324     310
# 132.1180    310
# 30.9680     310
# 33.3068     310
# 53.4712     310
# 50.9312     310
# 44.7624     310
# 19.5844     310
# 26.2980     310
# 75.0924     310
# 28.7000     310
# 56.4448     310
# 35.0380     310
# 146.5540    310
# 21.9668     310
# Name: DEM, dtype: int64

# %%
sns.countplot(df['DEM'])
plt.xticks(rotation = 90)
plt.tight_layout()

# %% [markdown]
# Elevation is same for almost all places.

# %% [markdown]
# now change year column splitting into moth and day and drop that column

# %%
df['month'] = pd.to_datetime(df['Date']).dt.month
df['day'] = pd.to_datetime(df['Date']).dt.day
df['year'] = pd.DatetimeIndex(df['Date']).year

# %%
df.groupby('year')['Next_Tmax'].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df.groupby('year')['Next_Tmin'].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# On Comparing with target variable which is next day minimum / maximum air temperature, we can see that 2016 has high air temperature and in terms of minimum we can see that 2013 and 2016 looks same and almost all year from 2013 - 2017, temperature seems to be same.
#
# There is no much difference but slight on 2014-2015 on minimum air temperature than other years.

# %%
df.groupby('month')['Next_Tmax'].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df.groupby('month')['Next_Tmin'].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# Comparing the month,Maximum air temperature on next day is having high temperature on month of October(10) than other months but there is no much difference and max air temperature is >30C.
#
# In terms of minimum air temperature on next day, we can see that almost all months looks same than August which is pretty less than others.So the minimum air temperature will be >20C

# %% [markdown]
# Dropping the date column as it has been splitted into day,month,year

# %%
df = df.drop(columns = ['Date'],axis = 1)

# %%
#now check dataset after splitting day month 
df.head()
# Out:
#    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0          28.7          21.4    58.255688    91.116364
# 1      2.0          31.9          21.6    52.263397    90.604721
# 2      3.0          31.6          23.3    48.690479    83.973587
# 3      4.0          32.0          23.4    58.239788    96.483688
# 4      5.0          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  ...  \
# 0         28.074101         23.006936  6.818887   69.451805   0.233947  ...
# 1         29.850689         24.035009  5.691890   51.937448   0.225508  ...
# 2         30.091292         24.565633  6.138224   20.573050   0.209344  ...
# 3         29.704629         23.326177  5.650050   65.727144   0.216372  ...
# 4         29.113934         23.486480  5.735004  107.965535   0.151407  ...
#
#        lat      lon       DEM   Slope  Solar radiation  Next_Tmax  Next_Tmin  \
# 0  37.6046  126.991  212.3350  2.7850      5992.895996       29.1       21.2
# 1  37.6046  127.032   44.7624  0.5141      5869.312500       30.5       22.5
# 2  37.5776  127.058   33.3068  0.2661      5863.555664       31.1       23.9
# 3  37.6450  127.022   45.7160  2.5348      5856.964844       31.7       24.3
# 4  37.5507  127.135   35.0380  0.5055      5859.552246       31.2       22.5
#
#    month   day    year
# 0    6.0  30.0  2013.0
# 1    6.0  30.0  2013.0
# 2    6.0  30.0  2013.0
# 3    6.0  30.0  2013.0
# 4    6.0  30.0  2013.0
#
# [5 rows x 27 columns]

# %% [markdown]
# Replacing NAN values to mean() values and mode () values

# %%
cols= ['Present_Tmax','Present_Tmin','LDAPS_RHmin','LDAPS_RHmax','LDAPS_Tmax_lapse','LDAPS_Tmin_lapse','LDAPS_WS','LDAPS_LH','LDAPS_CC1','LDAPS_CC2','LDAPS_CC3','LDAPS_CC4','LDAPS_PPT1','LDAPS_PPT2','LDAPS_PPT3','LDAPS_PPT4']
for i in cols:
    df[cols] = df[cols].fillna(df[cols].mean())

# %%
df['station'] = df['station'].fillna(df['station'].mode()[0])
df['month'] = df['month'].fillna(df['month'].mode()[0])
df['day'] = df['day'].fillna(df['day'].mode()[0])
df['year'] = df['year'].fillna(df['year'].mode()[0])

# %%
# checking null values after replacing and we can see target variables have null values,

df.isnull().sum()
# Out:
# station              0
# Present_Tmax         0
# Present_Tmin         0
# LDAPS_RHmin          0
# LDAPS_RHmax          0
# LDAPS_Tmax_lapse     0
# LDAPS_Tmin_lapse     0
# LDAPS_WS             0
# LDAPS_LH             0
# LDAPS_CC1            0
# LDAPS_CC2            0
# LDAPS_CC3            0
# LDAPS_CC4            0
# LDAPS_PPT1           0
# LDAPS_PPT2           0
# LDAPS_PPT3           0
# LDAPS_PPT4           0
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# month                0
# day                  0
# year                 0
# dtype: int64

# %% [markdown]
# dropping the target variable NAN rows as it will cause bias to the model.

# %%
df['Next_Tmax'] = df['Next_Tmax'].dropna()
df['Next_Tmin'] = df['Next_Tmin'].dropna()

# %%
df.isnull().sum()
# Out:
# station              0
# Present_Tmax         0
# Present_Tmin         0
# LDAPS_RHmin          0
# LDAPS_RHmax          0
# LDAPS_Tmax_lapse     0
# LDAPS_Tmin_lapse     0
# LDAPS_WS             0
# LDAPS_LH             0
# LDAPS_CC1            0
# LDAPS_CC2            0
# LDAPS_CC3            0
# LDAPS_CC4            0
# LDAPS_PPT1           0
# LDAPS_PPT2           0
# LDAPS_PPT3           0
# LDAPS_PPT4           0
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# month                0
# day                  0
# year                 0
# dtype: int64

# %%
df = df.dropna()  # dropping the na values and reset the index
df= df.reset_index(drop = True)

# %%
df
# Out:
#       station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0          28.7          21.4    58.255688    91.116364
# 1         2.0          31.9          21.6    52.263397    90.604721
# 2         3.0          31.6          23.3    48.690479    83.973587
# 3         4.0          32.0          23.4    58.239788    96.483688
# 4         5.0          31.4          21.9    56.174095    90.155128
# ...       ...           ...           ...          ...          ...
# 7720     23.0          23.3          17.1    26.741310    78.869858
# 7721     24.0          23.3          17.7    24.040634    77.294975
# 7722     25.0          23.2          17.4    22.933014    77.243744
# 7723      1.0          20.0          11.3    19.794666    58.936283
# 7724      1.0          37.6          29.9    98.524734   100.000153
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  LDAPS_CC1  \
# 0            28.074101         23.006936   6.818887   69.451805   0.233947
# 1            29.850689         24.035009   5.691890   51.937448   0.225508
# 2            30.091292         24.565633   6.138224   20.573050   0.209344
# 3            29.704629         23.326177   5.650050   65.727144   0.216372
# 4            29.113934         23.486480   5.735004  107.965535   0.151407
# ...                ...               ...        ...         ...        ...
# 7720         26.352081         18.775678   6.148918   72.058294   0.030034
# 7721         27.010193         18.733519   6.542819   47.241457   0.035874
# 7722         27.939516         18.522965   7.289264    9.090034   0.048954
# 7723         17.624954         14.272646   2.882580  -13.603212   0.000000
# 7724         38.542255         29.619342  21.857621  213.414006   0.967277
#
#       ...      lat      lon       DEM     Slope  Solar radiation  Next_Tmax  \
# 0     ...  37.6046  126.991  212.3350  2.785000      5992.895996       29.1
# 1     ...  37.6046  127.032   44.7624  0.514100      5869.312500       30.5
# 2     ...  37.5776  127.058   33.3068  0.266100      5863.555664       31.1
# 3     ...  37.6450  127.022   45.7160  2.534800      5856.964844       31.7
# 4     ...  37.5507  127.135   35.0380  0.505500      5859.552246       31.2
# ...   ...      ...      ...       ...       ...              ...        ...
# 7720  ...  37.5372  126.891   15.5876  0.155400      4443.313965       28.3
# 7721  ...  37.5237  126.909   17.2956  0.222300      4438.373535       28.6
# 7722  ...  37.5237  126.970   19.5844  0.271300      4451.345215       27.8
# 7723  ...  37.4562  126.826   12.3700  0.098475      4329.520508       17.4
# 7724  ...  37.6450  127.135  212.3350  5.178230      5992.895996       38.9
#
#       Next_Tmin  month   day    year
# 0          21.2    6.0  30.0  2013.0
# 1          22.5    6.0  30.0  2013.0
# 2          23.9    6.0  30.0  2013.0
# 3          24.3    6.0  30.0  2013.0
# 4          22.5    6.0  30.0  2013.0
# ...         ...    ...   ...     ...
# 7720       18.1    8.0  30.0  2017.0
# 7721       18.8    8.0  30.0  2017.0
# 7722       17.4    8.0  30.0  2017.0
# 7723       11.3    7.0   7.0  2013.0
# 7724       29.8    7.0   7.0  2013.0
#
# [7725 rows x 27 columns]

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7725.000000   7725.000000   7725.000000  7725.000000  7725.000000
# mean     13.005049     29.769552     23.224635    56.741576    88.369195
# std       7.215687      2.959205      2.405561    14.583630     7.164028
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    46.045017    84.291199
# 50%      13.000000     29.900000     23.400000    55.266701    89.699196
# 75%      19.000000     32.000000     24.900000    66.996681    93.704353
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7725.000000       7725.000000  7725.000000  7725.000000
# mean          29.616226         23.511815     7.096750    62.468953
# std            2.932271          2.333987     2.171835    33.556340
# min           17.624954         14.272646     2.882580   -13.603212
# 25%           27.696185         22.114277     5.686496    37.452979
# 50%           29.664030         23.733589     6.564141    57.299645
# 75%           31.687106         25.135301     7.996899    83.897461
# max           38.542255         29.619342    21.857621   213.414006
#
#          LDAPS_CC1  ...          lat          lon          DEM        Slope  \
# count  7725.000000  ...  7725.000000  7725.000000  7725.000000  7725.000000
# mean      0.368485  ...    37.544755   126.991370    61.926856     1.258725
# std       0.261052  ...     0.050386     0.079347    54.331701     1.371331
# min       0.000000  ...    37.456200   126.826000    12.370000     0.098475
# 25%       0.148229  ...    37.510200   126.937000    28.700000     0.271300
# 50%       0.319678  ...    37.550700   126.995000    45.716000     0.618000
# 75%       0.571547  ...    37.577600   127.042000    59.832400     1.767800
# max       0.967277  ...    37.645000   127.135000   212.335000     5.178230
#
#        Solar radiation    Next_Tmax    Next_Tmin        month          day  \
# count      7725.000000  7725.000000  7725.000000  7725.000000  7725.000000
# mean       5342.066031    30.274887    22.932220     7.079612    16.369061
# std         429.235277     3.128010     2.487613     2.238210     8.242621
# min        4329.520508    17.400000    11.300000     1.000000     7.000000
# 25%        4999.018555    28.200000    21.300000     7.000000     8.000000
# 50%        5437.534180    30.500000    23.100000     7.000000    16.000000
# 75%        5728.624512    32.600000    24.600000     8.000000    24.000000
# max        5992.895996    38.900000    29.800000    12.000000    31.000000
#
#               year
# count  7725.000000
# mean   2014.996893
# std       1.414027
# min    2013.000000
# 25%    2014.000000
# 50%    2015.000000
# 75%    2016.000000
# max    2017.000000
#
# [8 rows x 27 columns]

# %%
plt.figure(figsize = (10,10))
pltnumber = 1

for column in df:
    if pltnumber<=27:
        ax = plt.subplot(6,5,pltnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=10)
        pltnumber+=1
plt.tight_layout()

# %% [markdown]
# 1) LDAPS_PPT1 - 4 has high positive skewness ,
#
# 2) humidity max, lapse rate max /min has moderate negative skewness,
#
# 3) windspped , heat flux has moderate positive skewness,
#
# 4) CC1-4 has moderate positive skewness,
#
# 5) month has skewness on both positive and negative,
#
# 6) next day max / min air temperature columns has slightly skewed towards left side ie.negative.

# %%
 # null values has been treated now.
df.isnull().sum()
# Out:
# station             0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# month               0
# day                 0
# year                0
# dtype: int64

# %% [markdown]
# We will check the correlation between features vs features and features vs target and can see that it looks fine and we will proceed further.

# %%
#heat map
fig, ax = plt.subplots(figsize=(20,20))
sns.heatmap(df.corr(),cmap = 'Oranges_r', annot=True, linewidths=.5, ax=ax)
plt.show()

# %%
plt.figure(figsize = (10,10))
pltnumber = 1

for column in df:
    if pltnumber<=27:
        ax = plt.subplot(6,5,pltnumber)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=10)
        pltnumber+=1
plt.tight_layout()

# %%
df.skew()
# Out:
# station            -0.002671
# Present_Tmax       -0.264750
# Present_Tmin       -0.366521
# LDAPS_RHmin         0.302959
# LDAPS_RHmax        -0.854116
# LDAPS_Tmax_lapse   -0.227408
# LDAPS_Tmin_lapse   -0.580647
# LDAPS_WS            1.581465
# LDAPS_LH            0.673019
# LDAPS_CC1           0.460552
# LDAPS_CC2           0.475215
# LDAPS_CC3           0.642222
# LDAPS_CC4           0.666281
# LDAPS_PPT1          5.399231
# LDAPS_PPT2          5.782954
# LDAPS_PPT3          6.469458
# LDAPS_PPT4          6.833841
# lat                 0.086587
# lon                -0.286558
# DEM                 1.721056
# Slope               1.560549
# Solar radiation    -0.513787
# Next_Tmax          -0.339607
# Next_Tmin          -0.403743
# month              -0.704300
# day                 0.245795
# year                0.002471
# dtype: float64

# %% [markdown]
# Applying Power transform Method to remove the skewness from columns,

# %%
from sklearn.preprocessing import power_transform
df_New=power_transform(df)
df_New=pd.DataFrame(df_New,columns=df.columns)

# %%
df_New.skew()
# Out:
# station            -0.205824
# Present_Tmax       -0.035313
# Present_Tmin       -0.012386
# LDAPS_RHmin        -0.017149
# LDAPS_RHmax        -0.115691
# LDAPS_Tmax_lapse   -0.009266
# LDAPS_Tmin_lapse   -0.017697
# LDAPS_WS            0.002231
# LDAPS_LH            0.057105
# LDAPS_CC1           0.046895
# LDAPS_CC2           0.045528
# LDAPS_CC3           0.087874
# LDAPS_CC4           0.126559
# LDAPS_PPT1          1.405602
# LDAPS_PPT2          1.578999
# LDAPS_PPT3          1.748489
# LDAPS_PPT4          1.960554
# lat                 0.000000
# lon                -0.199755
# DEM                 0.039634
# Slope               0.233811
# Solar radiation    -0.177610
# Next_Tmax          -0.039261
# Next_Tmin          -0.014544
# month               0.044197
# day                -0.041666
# year                0.000345
# dtype: float64

# %%
# shuffling the data for better prediction
df = df.sample(frac = 1)

# %%
#splitting target and features
X = df.drop(columns = ['Next_Tmax','lat'],axis = 1)
y = df['Next_Tmax']

# %%
X.head()
# Out:
#       station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 6211      2.0          29.7          21.7    85.732025    97.570595
# 6432      1.0          23.5          21.6    70.782356    98.693283
# 3011     16.0          27.4          19.3    50.294857    84.058373
# 7123     18.0          33.6          25.9    52.954479    86.750916
# 6594     13.0          29.0          23.4    60.978119    87.498070
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  \
# 6211         26.344322         23.878456  8.865222   31.000296   0.894899
# 6432         27.420719         21.147421  7.000309   72.851770   0.314137
# 3011         28.185623         19.694127  5.686110   85.370873   0.043352
# 7123         32.866467         26.070037  6.402359  116.206800   0.020396
# 6594         31.815446         25.577788  6.961431   41.492087   0.428356
#
#       ...  LDAPS_PPT3  LDAPS_PPT4      lon       DEM   Slope  Solar radiation  \
# 6211  ...    0.238843    1.979121  127.032   44.7624  0.5141      5863.956055
# 6432  ...    0.000000    0.000000  126.991  212.3350  2.7850      5915.583496
# 3011  ...    0.000000    0.000000  126.995   82.2912  2.2579      4526.640625
# 7123  ...    0.000000    0.000000  127.024   56.4448  1.2313      5258.703613
# 6594  ...    0.000000    0.000000  127.083   59.8324  2.6865      5701.450195
#
#       Next_Tmin  month   day    year
# 6211       21.8    1.0   7.0  2017.0
# 6432       20.3   10.0   7.0  2017.0
# 3011       18.1    8.0  27.0  2014.0
# 7123       25.8    6.0   8.0  2017.0
# 6594       24.1    7.0  16.0  2017.0
#
# [5 rows x 25 columns]

# %%
y
# Out:
# 6211    27.5
# 6432    29.1
# 3011    29.7
# 7123    34.5
# 6594    30.7
#         ...
# 6759    27.8
# 3927    32.8
# 2587    28.8
# 3842    33.9
# 147     31.3
# Name: Next_Tmax, Length: 7725, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x= pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %%
x.head()
# Out:
#     station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0 -1.525255     -0.023505     -0.633837     1.988005     1.284472
# 1 -1.663851     -2.118798     -0.675410     0.962839     1.441194
# 2  0.415088     -0.800791     -1.631590    -0.442080    -0.601771
# 3  0.692280      1.294501      1.112230    -0.259698    -0.225904
# 4 -0.000700     -0.260071      0.072905     0.290519    -0.121605
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  ...  \
# 0         -1.115898          0.157098  0.814328 -0.937846   2.016644  ...
# 1         -0.748788         -1.013093 -0.044408  0.309435  -0.208203  ...
# 2         -0.487914         -1.635799 -0.649557  0.682536  -1.245555  ...
# 3          1.108510          1.096145 -0.319746  1.601525  -1.333495  ...
# 4          0.750054          0.885226 -0.062310 -0.625164   0.229360  ...
#
#    LDAPS_PPT3  LDAPS_PPT4       lon       DEM     Slope  Solar radiation  \
# 0   -0.033225    1.424848  0.512084 -0.315940 -0.543030         1.215939
# 1   -0.240486   -0.224551 -0.004668  2.768510  1.113060         1.336224
# 2   -0.240486   -0.224551  0.045747  0.374839  0.728664        -1.899840
# 3   -0.240486   -0.224551  0.411254 -0.100906 -0.020000        -0.194224
# 4   -0.240486   -0.224551  1.154872 -0.038552  1.041227         0.837320
#
#    Next_Tmin     month       day      year
# 0  -0.455173 -2.716458 -1.136734  1.416689
# 1  -1.058199  1.304872 -1.136734  1.416689
# 2  -1.942639  0.411243  1.289836 -0.705049
# 3   1.152899 -0.482386 -1.015406  1.416689
# 4   0.469468 -0.035572 -0.044778  1.416689
#
# [5 rows x 25 columns]

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR 
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split,cross_val_score,cross_val_predict,GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
#train test split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=128)

# %%
#check the shape of train test split
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((6180, 25), (1545, 25), (6180,), (1545,))

# %%
kn = KNeighborsRegressor()
dc = DecisionTreeRegressor()
rf = RandomForestRegressor()
xgb = XGBRegressor()
svm = SVR()
lin = LinearRegression

# %%
#randomforest regressior
rf.fit(x_train,y_train)
y_pred = rf.predict(x_test)
scr_rf = cross_val_score(rf,x,y,cv=5)

print("r2_Score", r2_score(y_test,y_pred))
print("CV Score", scr_rf.mean())
print("MSE",metrics.mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print("Train Score", rf.score(x_train,y_train))
print("Test Score", rf.score(x_test,y_test))


plt.scatter(y_test,y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
# Out:
# r2_Score 0.9136333260589898
# CV Score 0.9162243959317339
# MSE 0.8449812045307444
# RMSE 0.9192285920981486
# Train Score 0.9881008995427872
# Test Score 0.9136333260589898

# %%
#decision tree regression
dc.fit(x_train,y_train)
y_pred = dc.predict(x_test)
scr_dc = cross_val_score(dc,x,y,cv=5)

print("r2_Score", r2_score(y_test,y_pred))
print("CV Score", scr_dc.mean())
print("MSE",metrics.mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print("Train Score", dc.score(x_train,y_train))
print("Test Score", dc.score(x_test,y_test))


plt.scatter(y_test,y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
# Out:
# r2_Score 0.8034009240282456
# CV Score 0.8048726284926879
# MSE 1.9234563106796114
# RMSE 1.3868872739626719
# Train Score 1.0
# Test Score 0.8034009240282456

# %%
#KNeighborsRegressor
kn.fit(x_train,y_train)
y_pred = kn.predict(x_test)
scr_kn = cross_val_score(kn,x,y,cv=5)

print("r2_Score", r2_score(y_test,y_pred))
print("CV Score", scr_kn.mean())
print("MSE",metrics.mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print("Train Score", kn.score(x_train,y_train))
print("Test Score", kn.score(x_test,y_test))


plt.scatter(y_test,y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
# Out:
# r2_Score 0.9029165191304528
# CV Score 0.9033236390571316
# MSE 0.9498306796116504
# RMSE 0.9745925710837582
# Train Score 0.9369286948017873
# Test Score 0.9029165191304528

# %%
#gradient boost regression
xgb.fit(x_train, y_train)
y_pred = xgb.predict(x_test)
scr_xgb = cross_val_score(xgb,x,y,cv=5)

print("r2_Score", r2_score(y_test,y_pred))
print("CV Score", scr_xgb.mean())
print("MSE",metrics.mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print("Train Score", xgb.score(x_train,y_train))
print("Test Score", xgb.score(x_test,y_test))

plt.scatter(y_test,y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
# Out:
# r2_Score 0.9284824132813292
# CV Score 0.9320396718932121
# MSE 0.6997029503758568
# RMSE 0.8364824865924312
# Train Score 0.9902189507203777
# Test Score 0.9284824132813292

# %%
#linear regression

lin.fit(x_train,y_train)
y_pred = lin.predict(x_test)
scr_lin = cross_val_score(lin,x,y,cv=5)

print("r2_Score", r2_score(y_test,y_pred))
print("CV Score", scr_lin.mean())
print("MSE",metrics.mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print("Train Score", lin.score(x_train,y_train))
print("Test Score", lin.score(x_test,y_test))

plt.scatter(y_test,y_pred, color = 'green')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
# Out:
# r2_Score 0.788506941880103
# CV Score 0.7945249143221063
# MSE 2.069173801020769
# RMSE 1.4384623043447364
# Train Score 0.798286838250169
# Test Score 0.788506941880103

# %%
#svm
svm.fit(x_train,y_train)
y_pred = svm.predict(x_test)
scr_svm = cross_val_score(svm,x,y,cv=5)

print("r2_Score", r2_score(y_test,y_pred))
print("CV Score", scr_svm.mean())
print("MSE",metrics.mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print("Train Score", svm.score(x_train,y_train))
print("Test Score", svm.score(x_test,y_test))

plt.scatter(y_test,y_pred, color = 'green')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
# Out:
# r2_Score 0.8879114755319845
# CV Score 0.8890127936630364
# MSE 1.096634756176299
# RMSE 1.0472033022180072
# Train Score 0.9095219889185813
# Test Score 0.8879114755319845

# %% [markdown]
# Comparing Cross val score with accuracy score of model, "RANDOM FOREST" is the best model as it is having less difference of 0.03 and the model which is having less difference is considered as best model.
#
# Applying Hyper parameter tuning to the best model to check the accuracy score,

# %% [markdown]
# # Hyper Parameter Tuning

# %%
params = {'n_estimators':[20,70,100],
          'max_depth':[None,5,10],
          'min_samples_split':[2,7],
          'min_samples_leaf':[1,2,4]
           }

# %%
grid_search = GridSearchCV(rf,params,cv=3,verbose = 2,n_jobs = 4)

# %%
grid_search.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# GridSearchCV(cv=3, estimator=RandomForestRegressor(), n_jobs=4,
#              param_grid={'max_depth': [None, 5, 10],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 7],
#                          'n_estimators': [20, 70, 100]},
#              verbose=2)

# %%
grid_search.best_params_
# Out:
# {'max_depth': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 100}

# %%
final_model = RandomForestRegressor(criterion = 'mse', max_depth = None, min_samples_leaf = 1, min_samples_split = 2, n_estimators = 100)
final_model.fit(x_train, y_train)
y_predict = final_model.predict(x_test)
print ('r2_Score:',r2_score(y_test,y_predict))
print('MAE:', metrics.mean_absolute_error(y_test, y_predict))
print('MSE:', metrics.mean_squared_error(y_test, y_predict))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_predict)))
# Out:
# r2_Score: 0.9138737190951041
# MAE: 0.6847514563106799
# MSE: 0.8426292834951455
# RMSE: 0.9179484100400989

# %%
print("r2_Score:", r2_score(y_test,y_predict))
print("Train Score:", final_model.score(x_train,y_train))
print("Test Score:", final_model.score(x_test,y_test))
# Out:
# r2_Score: 0.9138737190951041
# Train Score: 0.9880732836902151
# Test Score: 0.9138737190951041

# %%
cross_val_score(final_model,x,y,cv=5).mean()
# Out:
# 0.9154987833125275

# %%
#plot predicted actual,predicted and model
plt.scatter(x = y_test, y = y_predict, color = 'orange')
plt.plot(y_test, y_test, color = 'orange')
plt.xlabel('Actual', fontsize = 14)
plt.ylabel('Predicted', fontsize = 14)
plt.title('RandomForestRegressor', fontsize = 18)
plt.show()

# %% [markdown]
# Afterb hyperparameterb tuning our good accuracy score is 92%

# %% [markdown]
# We can see that model is linear and distance between residuals and best fit line is less and that proves that model is good,even though we can see some points far from the best fit line but very few.

# %%
import joblib
joblib.dump(final_model,"max_temp.prediction")
# Out:
# ['max_temp.prediction']

# %% [markdown]
# Next target variable

# %%
df
# Out:
#       station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 1465     19.0          29.6          20.9    56.363712    76.769135
# 6254     21.0          27.1          22.8    81.267517    99.051132
# 2129      8.0          25.2          22.9    55.264431    95.862045
# 1459     13.0          30.3          23.2    50.432480    79.255280
# 1637     16.0          23.5          19.5    43.987080    85.445656
# ...       ...           ...           ...          ...          ...
# 1233     12.0          32.2          25.5    48.774727    93.553177
# 2032     11.0          30.6          25.4    49.017315    86.248360
# 4972     10.0          27.5          19.6    47.810684    89.368927
# 1207     11.0          34.1          27.4    52.632408    90.389832
# 6873     17.0          27.7          22.6    76.845428    92.629379
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  LDAPS_CC1  \
# 1465         28.477554         23.941267   6.081727   46.843936   0.217692
# 6254         26.001139         23.352914  10.323340   43.734842   0.855084
# 2129         29.222145         22.240657   4.069215   50.760286   0.762600
# 1459         29.314304         22.981679   5.936901   28.326196   0.146543
# 1637         30.113299         20.892356   5.824990  102.209189   0.315165
# ...                ...               ...        ...         ...        ...
# 1233         31.760090         25.201052   6.349147   47.017572   0.527513
# 2032         32.230285         25.453630   6.912038   57.425618   0.137099
# 4972         29.488116         22.290074   7.646404   74.729656   0.217911
# 1207         31.945402         26.882635   8.855688   62.788879   0.243813
# 6873         26.216622         23.579513   4.720797   42.030451   0.601725
#
#       ...      lat      lon       DEM   Slope  Solar radiation  Next_Tmax  \
# 1465  ...  37.5776  126.938   75.0924  1.7678      4612.763672       30.6
# 6254  ...  37.5507  127.040   26.2980  0.5721      5848.048828       28.2
# 2129  ...  37.4697  126.910   52.5180  1.5629      5586.337402       25.2
# 1459  ...  37.5776  127.083   59.8324  2.6865      4553.020020       31.5
# 1637  ...  37.4697  126.995   82.2912  2.2579      5842.662598       31.8
# ...   ...      ...      ...       ...     ...              ...        ...
# 1233  ...  37.5507  126.988  132.1180  0.5931      4951.879883       33.3
# 2032  ...  37.5372  127.085   28.7000  0.6233      5663.089355       33.1
# 4972  ...  37.4562  126.955  208.5070  5.1782      5750.477539       31.2
# 1207  ...  37.5372  127.085   28.7000  0.6233      4942.246582       34.2
# 6873  ...  37.6181  127.099   53.4712  0.6970      5518.565430       25.8
#
#       Next_Tmin  month   day    year
# 1465       21.3    8.0  27.0  2013.0
# 6254       22.2    2.0   7.0  2017.0
# 2129       19.0    7.0  23.0  2014.0
# 1459       22.8    8.0  27.0  2013.0
# 1637       20.3    3.0   7.0  2014.0
# ...         ...    ...   ...     ...
# 1233       24.0    8.0  18.0  2013.0
# 2032       25.5    7.0  19.0  2014.0
# 4972       23.0    7.0  13.0  2016.0
# 1207       27.5    8.0  17.0  2013.0
# 6873       23.2    7.0  27.0  2017.0
#
# [7725 rows x 27 columns]

# %%
df = df.sample(frac = 1)

# %%
#splitting feature and weight
X = df.drop(columns = ['Next_Tmin','lat'],axis = 1)
y = df['Next_Tmin']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x= pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %%
x.head()
# Out:
#     station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0  1.662451      1.395887      1.694253    -0.041898    -0.848089
# 1 -0.555083      1.294501      1.236949     1.872189     0.598930
# 2  0.137896     -0.733201     -1.714736    -0.744510    -0.002449
# 3 -0.832275     -0.057300     -0.425972    -1.115119     0.690070
# 4 -0.139296     -0.158685     -0.550691    -0.594882    -0.573629
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  ...  \
# 0          0.199695          1.329643 -0.814593 -1.610137  -0.281754  ...
# 1         -0.328499          1.309133 -1.145893 -0.962678  -0.270610  ...
# 2          0.254631         -0.212227 -0.334467 -1.436766  -0.560255  ...
# 3          1.221759         -0.271024 -0.782879  2.545918  -0.785302  ...
# 4          0.392585          0.329906 -0.411086 -1.367958   0.020839  ...
#
#    LDAPS_PPT3  LDAPS_PPT4       lon       DEM     Slope  Solar radiation  \
# 0   -0.240486   -0.224551 -0.269346 -0.779383 -0.720096        -0.250538
# 1    0.452501   -0.224151 -2.084278 -0.202393 -0.617123        -0.686980
# 2   -0.240486   -0.224551 -0.811305 -0.569849 -0.467259        -0.524395
# 3   -0.240486   -0.224551 -1.933034 -0.912176 -0.846113         0.881249
# 4   -0.240486   -0.224551 -0.042479  1.291984 -0.485418        -1.154961
#
#    Next_Tmax     month       day      year
# 0   0.519569 -0.035572 -1.015406  1.416689
# 1   0.903225  0.411243 -0.408763  0.709443
# 2  -0.023942  1.751686 -1.015406 -0.705049
# 3   1.127024 -0.035572 -0.287435  0.002197
# 4   0.711397  0.411243  0.561865  1.416689
#
# [5 rows x 25 columns]

# %%
#Train Test Split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.20, random_state = 333)

# %%
svm.fit(x_train,y_train)
y_pred = svm.predict(x_test)
scr_svm = cross_val_score(svm,x,y,cv=5)

print("r2_Score", r2_score(y_test,y_pred))
print("CV Score", scr_svm.mean())
print("MSE",metrics.mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print("Train Score", svm.score(x_train,y_train))
print("Test Score", svm.score(x_test,y_test))

plt.scatter(y_test,y_pred, color = 'blue')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
# Out:
# r2_Score 0.9116512197455121
# CV Score 0.9091270046849861
# MSE 0.5291707570407257
# RMSE 0.7274412395793393
# Train Score 0.9296360711493321
# Test Score 0.9116512197455121

# %%
#RandomForestRegressor
rf.fit(x_train,y_train)
y_pred = rf.predict(x_test)
scr_rf = cross_val_score(rf,x,y,cv=5)

print("r2_Score", r2_score(y_test,y_pred))
print("CV Score", scr_rf.mean())
print("MSE",metrics.mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print("Train Score", rf.score(x_train,y_train))
print("Test Score", rf.score(x_test,y_test))

plt.scatter(y_test,y_pred, color = 'blue')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
# Out:
# r2_Score 0.9061645437530372
# CV Score 0.911754068214789
# MSE 0.562033559223301
# RMSE 0.7496889749911633
# Train Score 0.9878325055680329
# Test Score 0.9061645437530372

# %%
# LinearRegression

lin.fit(x_train,y_train)
y_pred = lin.predict(x_test)
scr_lin = cross_val_score(lin,x,y,cv=5)

print("r2_Score", r2_score(y_test,y_pred))
print("CV Score", scr_lin.mean())
print("MSE",metrics.mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print("Train Score", lin.score(x_train,y_train))
print("Test Score", lin.score(x_test,y_test))

plt.scatter(y_test,y_pred, color = 'green')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
# Out:
# r2_Score 0.8395921641026337
# CV Score 0.8494752214408313
# MSE 0.9607731506034224
# RMSE 0.9801903644718317
# Train Score 0.8530474354633558
# Test Score 0.8395921641026337

# %%
from sklearn.ensemble import AdaBoostRegressor

abr = AdaBoostRegressor()
abr.fit(x_train,y_train)
y_pred = abr.predict(x_test)
scr_abr = cross_val_score(abr,x,y,cv=5)

print("r2_Score", r2_score(y_test,y_pred))
print("CV Score", scr_abr.mean())
print("MSE",metrics.mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print("Train Score", abr.score(x_train,y_train))
print("Test Score", abr.score(x_test,y_test))

plt.scatter(y_test,y_pred, color = 'blue')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
# Out:
# r2_Score 0.8020022811958328
# CV Score 0.8136330035632087
# MSE 1.18592019550395
# RMSE 1.088999630626177
# Train Score 0.8282810092356281
# Test Score 0.8020022811958328

# %%
#gradien boost regressior
xgb.fit(x_train, y_train)
y_pred = xgb.predict(x_test)
scr_gbr = cross_val_score(xgb,x,y,cv=5)

print("r2_Score", r2_score(y_test,y_pred))
print("CV Score", scr_xgb.mean())
print("MSE",metrics.mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print("Train Score", xgb.score(x_train,y_train))
print("Test Score", xgb.score(x_test,y_test))

plt.scatter(y_test,y_pred, color = 'red')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
# Out:
# r2_Score 0.9320857935526188
# CV Score 0.9320396718932121
# MSE 0.4067765501239643
# RMSE 0.6377903653426918
# Train Score 0.9922896331361526
# Test Score 0.9320857935526188

# %% [markdown]
# Comparing Cross val score with accuracy score of model, "GradientBoostRegressior" is the best model as it is having less difference of 0.03 and the model which is having less difference is considered as best model.

# %% [markdown]
# Applying Hyper parameter tuning to increase the accuracy of the model

# %% [markdown]
# # Hyper Parameter Tuning

# %%
params = {
            'max_depth': range (2, 10, 1),
            'n_estimators': range(60, 220, 40),
            'learning_rate': [0.1, 0.01, 0.05]
}

# %%
grid_search = GridSearchCV(xgb, params, cv = 3)

# %%
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0, gpu_id=-1,
#                                     importance_type='gain',
#                                     interaction_constraints='',
#                                     learning_rate=0.300000012, max_delta_step=0,
#                                     max_depth=6, min_child_weight=1,
#                                     missing=nan, monotone_constraints='()',
#                                     n_estimators=100, n_jobs=8,
#                                     num_parallel_tree=1, random_state=0,
#                                     reg_alpha=0, reg_lambda=1,
#                                     scale_pos_weight=1, subsample=1,
#                                     tree_method='exact', validate_parameters=1,
#                                     verbosity=None),
#              param_grid={'learning_rate': [0.1, 0.01, 0.05],
#                          'max_depth': range(2, 10),
#                          'n_estimators': range(60, 220, 40)})

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 180}

# %%
final_model =XGBRegressor(learning_rate =  0.1,max_depth = 8,n_estimators = 180)
final_model.fit(x_train, y_train)
y_predict = final_model.predict(x_test)
print ('r2_Score:',r2_score(y_test,y_predict))
print('MAE:', metrics.mean_absolute_error(y_test, y_predict))
print('MSE:', metrics.mean_squared_error(y_test, y_predict))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_predict)))
# Out:
# r2_Score: 0.9406399010371232
# MAE: 0.44847601202313575
# MSE: 0.3555411678091872
# RMSE: 0.5962727293857965

# %%
print("r2_Score:", r2_score(y_test,y_predict))
print("Train Score:", final_model.score(x_train,y_train))
print("Test Score:", final_model.score(x_test,y_test))
# Out:
# r2_Score: 0.9406399010371232
# Train Score: 0.9967766407893279
# Test Score: 0.9406399010371232

# %%
cross_val_score(final_model,x,y,cv=5).mean()
# Out:
# 0.9469949088834962

# %%
#plot predicted actual,predicted and model
plt.scatter(x = y_test, y = y_predict, color = 'red')
plt.plot(y_test, y_test, color = 'red')
plt.xlabel('Actual', fontsize = 14)
plt.ylabel('Predicted', fontsize = 14)
plt.title('GradientBoostRegressor', fontsize = 18)
plt.show()

# %% [markdown]
# After hyper poaramater tuning my final model increased 2% so after that my final model accuracy score is 95%

# %% [markdown]
# Based on scatter plot, we can see that plot is linear and the distance between best fit line and residuals are kind of less.

# %% [markdown]
# # Saving the Model

# %%
import joblib
joblib.dump(final_model,"min_temp.prediction")
# Out:
# ['min_temp.prediction']
