# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_profiling import ProfileReport
import warnings
warnings.filterwarnings('ignore')

# %%
#read csv file using pandas dataframe
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/loan_prediction.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %% [markdown]
# here total we have 614 rows and 13 columns in the given dataset

# %%
#call first five rows
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %% [markdown]
# here it is first five rows

# %%
#shape of the full dataset
df.shape
# Out:
# (614, 13)

# %%
#check data at high level with statistically
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# Here in the count there are not equal some missing values are present
# describe shows the mean,counts ,min,max,quantile values of each column of numerical values.
# Each feature has difference scale range it show min,max and std

# %%
#plot the histogram to visualize the data
sns.set_theme()
df.hist(figsize = (20,20), bins = 20)
plt.show()

# %% [markdown]
# here graph showing we can see the col credit history has only two values which is 1 / 0 and col loan amount term is right skwed mostly ,Loan amount term can be anything depends on applicant loan amount and the plan he/she chosen.So removing these data will have a serious impact on our dataset and will affect our model for better prediction.

# %%
#check information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# here we observed our data set have dtypes are 8object and 4floattype and 1inttype and saying there are to find some missing values

# %%
#check NaN values
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#to visualise missing values with heatmap
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# there are some missing values are present

# %% [markdown]
# we treat missing after sometime

# %%
#check duplicate values 
sum(df.duplicated())
# Out:
# 0

# %% [markdown]
# no duplicate values in dataset

# %%
#check unique values
df.nunique()
# Out:
# Loan_ID              614
# Gender                 2
# Married                2
# Dependents             4
# Education              2
# Self_Employed          2
# ApplicantIncome      505
# CoapplicantIncome    287
# LoanAmount           203
# Loan_Amount_Term      10
# Credit_History         2
# Property_Area          3
# Loan_Status            2
# dtype: int64

# %% [markdown]
# no unique values in dtaset

# %% [markdown]
# # EDA

# %%
df['Loan_Status'].value_counts()
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
#let’s visualize the count of target variable using Seaborn
sns.countplot(df['Loan_Status'])
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %% [markdown]
# Our target column has imbalanced data we need to do balance we do after some time

# %%
df['Gender'].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
#let’s visualize the count of Gender using Seaborn
plt.figure(figsize=(10, 7))
sns.countplot(x='Gender', hue='Loan_Status',data= df )
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# Male peoples  have more laoan_status counts  is more than female and loan is approving for most of the males than females.

# %%
df['Married'].value_counts()
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
#let’s visualize the count of Married using Seaborn
plt.figure(figsize=(10, 7))
sns.countplot(x='Married', hue='Loan_Status',data= df )
# Out:
# <AxesSubplot:xlabel='Married', ylabel='count'>

# %% [markdown]
# Loan applicants who have applied for loan is married mostly and checking with target variable,we can see clearly that loan is sanctioning for most of the married people than un-married

# %%
df['Dependents'].value_counts()
# Out:
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64

# %%
#let’s visualize the count of Dependents using Seaborn
plt.figure(figsize=(10, 7))
sns.countplot(x='Dependents', hue='Loan_Status',data= df )
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %% [markdown]
# applicants who is not having any dependants is high in count and also from the above bar plot, we can see that Applicants who is having 0 dependants having high chance of getting his/her loan approved.

# %%
df['Self_Employed'].value_counts()
# Out:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64

# %%
#let’s visualize the count of Self_Employed using Seaborn
plt.figure(figsize=(10, 7))
sns.countplot(x='Self_Employed', hue='Loan_Status',data= df )
# Out:
# <AxesSubplot:xlabel='Self_Employed', ylabel='count'>

# %% [markdown]
# So most of the applicants are not self employed and upon checking with target variable it is clear that loan is getting approve for most of the employed people who is not belong to self-employed category.

# %%
df['Education'].value_counts()
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64

# %%
#let’s visualize the count of Education using Seaborn
plt.figure(figsize=(10, 7))
sns.countplot(x='Education', hue='Loan_Status',data= df )
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %% [markdown]
# Applicants are mostly Graduate in the given dataset and in terms of education,loan is getting approved for graduates than not graduate applicants.

# %%
df['Property_Area'].value_counts()
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64

# %%
#let’s visualize the count of Property_Area using Seaborn
plt.figure(figsize=(10, 7))
sns.countplot(x='Property_Area', hue='Loan_Status',data= df )
# Out:
# <AxesSubplot:xlabel='Property_Area', ylabel='count'>

# %% [markdown]
# Applicants applying for loan is having property area to get the loan and our dataset is showing that Semi-Urban property area ranks high and loan is getting approval for the applicants who is having property in Semi - Urban and then Urban places.

# %%
df['Credit_History'].value_counts()
# Out:
# 1.0    475
# 0.0     89
# Name: Credit_History, dtype: int64

# %%
#let’s visualize the count of Credit_History using Seaborn
plt.figure(figsize=(10, 7))
sns.countplot(x='Credit_History', hue='Loan_Status',data= df )
# Out:
# <AxesSubplot:xlabel='Credit_History', ylabel='count'>

# %% [markdown]
# we can see that most of the applicants have credit history and in terms of loan status, the applicants who are having credit history has high chances of getting loan approved.

# %%
df['Loan_Amount_Term'].value_counts()
# Out:
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 84.0       4
# 240.0      4
# 120.0      3
# 36.0       2
# 60.0       2
# 12.0       1
# Name: Loan_Amount_Term, dtype: int64

# %%
#let’s visualize the count of Loan_Amount_Term using Seaborn
plt.figure(figsize=(10, 7))
sns.countplot(x='Loan_Amount_Term', hue='Loan_Status',data= df )
# Out:
# <AxesSubplot:xlabel='Loan_Amount_Term', ylabel='count'>

# %% [markdown]
# So we can see that our dataset is having the loan amount term has 360 in months,and in terms of loan status,applicants who have avail loan for 360 in months are having more chances for getting the loan approved.

# %% [markdown]
# Now ourv data is not cleaned till now we make it first
#
# in above we ibserved there are have missingvalues we do work with that
#
# first do splitting the categorical and numerical data from the dataset

# %%
num_col = df.select_dtypes(exclude = np.object)
cat_col = df.select_dtypes(include = np.object)

# %%
#check null values in num_col
num_col.isnull().sum()
# Out:
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# dtype: int64

# %% [markdown]
# treat missing values numerical data with mean and catergorical do with mode

# %%
num_col['LoanAmount'] = num_col['LoanAmount'].fillna(num_col['LoanAmount'].mean())
num_col['Loan_Amount_Term'] = num_col['Loan_Amount_Term'].fillna(num_col['Loan_Amount_Term'].mean())
num_col['Credit_History'] = num_col['Credit_History'].fillna(num_col['Credit_History'].mode()[0])
num_col['CoapplicantIncome'] = num_col['CoapplicantIncome'].replace(0,num_col['CoapplicantIncome'].mean())

# %%
#check treated null values
num_col.isnull().sum()
# Out:
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# dtype: int64

# %% [markdown]
# all null values are cleared

# %%
#now check categorical missing values
cat_col.isnull().sum()
# Out:
# Loan_ID           0
# Gender           13
# Married           3
# Dependents       15
# Education         0
# Self_Employed    32
# Property_Area     0
# Loan_Status       0
# dtype: int64

# %% [markdown]
# we traet the missing values with categorical data  by  mode because of categorical missing values  we cant fill by mean

# %%
cat_col['Gender'] = cat_col['Gender'].fillna(cat_col['Gender'].mode()[0])
cat_col['Married'] = cat_col['Married'].fillna(cat_col['Married'].mode()[0])
cat_col['Dependents'] = cat_col['Dependents'].fillna(cat_col['Dependents'].mode()[0])
cat_col['Self_Employed'] = cat_col['Self_Employed'].fillna(cat_col['Self_Employed'].mode()[0])

# %%
#now check again after treated categorical missing values
cat_col.isnull().sum()
# Out:
# Loan_ID          0
# Gender           0
# Married          0
# Dependents       0
# Education        0
# Self_Employed    0
# Property_Area    0
# Loan_Status      0
# dtype: int64

# %% [markdown]
# filled our null values

# %%
cat_col.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# 3         Urban           Y
# 4         Urban           Y

# %% [markdown]
# covert categorical data into numerical datab using labelencoder

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
cat_col = cat_col.apply(labelencoder.fit_transform)

# %%
#how data distributed every column by visualization
plt.figure(figsize = (10,5))
plotnumber = 1

for column in num_col:
    if plotnumber<=6:
        ax = plt.subplot(2,3,plotnumber)
        sns.distplot(num_col[column])
        plt.xlabel(column,fontsize = 20)
               
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# our distribution of Applicantincome data id rightskewed,Coapplicanincome data skewed right,loan amount also right skewed,loan_amount_term is skewed left and credit_history both left and right skwed but mostly high in lrft only
# and so many outliers are present check outliers using box plot

# %%
#use boxplot
fig,ax = plt.subplots(ncols=3,nrows=2,figsize=(20,10))
index=0
ax = ax.flatten()

for col, value in num_col.items():
    if col !='type':
        sns.boxplot(y=col,data=num_col,ax=ax[index])
        index+= 1

# %% [markdown]
# ya here in every column having outliers but in this problem if we do remove outlers we lost important data in every column
# As per the above plot, We confirmed that column - "ApplicantIncome" and "CoapplicantIncome" is having outliers but, if you look into the data,it is about the income of the applicants.
# There is a possibility that applicants salary will be > 10K .So we can't remove the outliers here in this case as it will be resulting in loss of most important data.
# It is showing clearly that loan amount can be of any amount starting from > 1L ,here we can see outliers for >3L and as we can't remove these data as we will lose most important data.
# but we do once remove outlier bit do model building with without removed outliers

# %%
from scipy.stats import zscore
z=zscore(num_col)
z
# Out:
# array([[ 0.07299082, -0.2752068 ,  0.        ,  0.27985054,  0.41173269],
#        [-0.13441195, -0.31844206, -0.21927331,  0.27985054,  0.41173269],
#        [-0.39374734, -0.2752068 , -0.957641  ,  0.27985054,  0.41173269],
#        ...,
#        [ 0.43717437, -0.80254228,  1.26937121,  0.27985054,  0.41173269],
#        [ 0.35706382, -0.2752068 ,  0.4833669 ,  0.27985054,  0.41173269],
#        [-0.13441195, -0.2752068 , -0.15972753,  0.27985054, -2.42876026]])

# %%
threshold = 3
print (np.where(z>3))
# Out:
# (array([  9, 126, 130, 155, 155, 171, 171, 177, 177, 183, 185, 278, 308,
#        333, 333, 369, 402, 409, 417, 432, 443, 487, 506, 523, 525, 561,
#        581, 600, 604], dtype=int64), array([1, 0, 2, 0, 2, 0, 2, 1, 2, 0, 0, 2, 2, 0, 2, 2, 1, 0, 1, 2, 0, 2,
#        2, 2, 2, 2, 1, 1, 2], dtype=int64))

# %%
df_new = num_col [(z<3).all(axis = 1)]

# %% [markdown]
# checking for Skewness

# %%
df_new.skew()
# Out:
# ApplicantIncome      2.164762
# CoapplicantIncome    2.554282
# LoanAmount           1.076221
# Loan_Amount_Term    -2.433130
# Credit_History      -2.010069
# dtype: float64

# %%
from sklearn.preprocessing import power_transform 
df_New=power_transform(df_new)
df_New=pd.DataFrame(df_New,columns=num_col.columns)

# %%
df_New.skew()
# Out:
# ApplicantIncome      0.028063
# CoapplicantIncome    0.202442
# LoanAmount           0.060143
# Loan_Amount_Term     0.396698
# Credit_History      -2.010069
# dtype: float64

# %% [markdown]
# skewnessn are cleared but according problem featutes if clean the skewness get too much of data is loss

# %%
#now merging both numeric and categorical columns
df1 = pd.concat([num_col,cat_col],axis = 1)
df1
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849        1621.245798  146.412162             360.0
# 1               4583        1508.000000  128.000000             360.0
# 2               3000        1621.245798   66.000000             360.0
# 3               2583        2358.000000  120.000000             360.0
# 4               6000        1621.245798  141.000000             360.0
# ..               ...                ...         ...               ...
# 609             2900        1621.245798   71.000000             360.0
# 610             4106        1621.245798   40.000000             180.0
# 611             8072         240.000000  253.000000             360.0
# 612             7583        1621.245798  187.000000             360.0
# 613             4583        1621.245798  133.000000             360.0
#
#      Credit_History  Loan_ID  Gender  Married  Dependents  Education  \
# 0               1.0        0       1        0           0          0
# 1               1.0        1       1        1           1          0
# 2               1.0        2       1        1           0          0
# 3               1.0        3       1        1           0          1
# 4               1.0        4       1        0           0          0
# ..              ...      ...     ...      ...         ...        ...
# 609             1.0      609       0        0           0          0
# 610             1.0      610       1        1           3          0
# 611             1.0      611       1        1           1          0
# 612             1.0      612       1        1           2          0
# 613             0.0      613       0        0           0          0
#
#      Self_Employed  Property_Area  Loan_Status
# 0                0              2            1
# 1                0              0            0
# 2                1              2            1
# 3                0              2            1
# 4                0              2            1
# ..             ...            ...          ...
# 609              0              0            1
# 610              0              0            1
# 611              0              2            1
# 612              0              2            1
# 613              1              1            0
#
# [614 rows x 13 columns]

# %%
df1.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849        1621.245798  146.412162             360.0
# 1             4583        1508.000000  128.000000             360.0
# 2             3000        1621.245798   66.000000             360.0
# 3             2583        2358.000000  120.000000             360.0
# 4             6000        1621.245798  141.000000             360.0
#
#    Credit_History  Loan_ID  Gender  Married  Dependents  Education  \
# 0             1.0        0       1        0           0          0
# 1             1.0        1       1        1           1          0
# 2             1.0        2       1        1           0          0
# 3             1.0        3       1        1           0          1
# 4             1.0        4       1        0           0          0
#
#    Self_Employed  Property_Area  Loan_Status
# 0              0              2            1
# 1              0              0            0
# 2              1              2            1
# 3              0              2            1
# 4              0              2            1

# %%
#check correlation b/w features and target variables
df1.corr()
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.050734    0.565620
# CoapplicantIncome        -0.050734           1.000000    0.205388
# LoanAmount                0.565620           0.205388    1.000000
# Loan_Amount_Term         -0.045242          -0.073197    0.038801
# Credit_History           -0.018615           0.008339   -0.001431
# Loan_ID                   0.016925           0.048022    0.035684
# Gender                    0.058809           0.024156    0.107930
# Married                   0.051708          -0.017504    0.147141
# Dependents                0.118202           0.031776    0.163106
# Education                -0.140760          -0.088032   -0.166998
# Self_Employed             0.127180           0.013265    0.115260
# Property_Area            -0.009500           0.028111   -0.044776
# Loan_Status              -0.004710          -0.089189   -0.036416
#
#                    Loan_Amount_Term  Credit_History   Loan_ID    Gender  \
# ApplicantIncome           -0.045242       -0.018615  0.016925  0.058809
# CoapplicantIncome         -0.073197        0.008339  0.048022  0.024156
# LoanAmount                 0.038801       -0.001431  0.035684  0.107930
# Loan_Amount_Term           1.000000        0.000432 -0.028945 -0.073567
# Credit_History             0.000432        1.000000 -0.030603  0.009170
# Loan_ID                   -0.028945       -0.030603  1.000000 -0.028029
# Gender                    -0.073567        0.009170 -0.028029  1.000000
# Married                   -0.100863        0.010938 -0.016013  0.364569
# Dependents                -0.101054       -0.040160  0.051559  0.172914
# Education                 -0.077242       -0.073658  0.039442  0.045364
# Self_Employed             -0.033943       -0.001550  0.032874 -0.000525
# Property_Area             -0.077620        0.001963 -0.155416 -0.025752
# Loan_Status               -0.020974        0.540556  0.011773  0.017987
#
#                     Married  Dependents  Education  Self_Employed  \
# ApplicantIncome    0.051708    0.118202  -0.140760       0.127180
# CoapplicantIncome -0.017504    0.031776  -0.088032       0.013265
# LoanAmount         0.147141    0.163106  -0.166998       0.115260
# Loan_Amount_Term  -0.100863   -0.101054  -0.077242      -0.033943
# Credit_History     0.010938   -0.040160  -0.073658      -0.001550
# Loan_ID           -0.016013    0.051559   0.039442       0.032874
# Gender             0.364569    0.172914   0.045364      -0.000525
# Married            1.000000    0.334216   0.012304       0.004489
# Dependents         0.334216    1.000000   0.055752       0.056798
# Education          0.012304    0.055752   1.000000      -0.010383
# Self_Employed      0.004489    0.056798  -0.010383       1.000000
# Property_Area      0.004257   -0.000244  -0.065243      -0.030860
# Loan_Status        0.091478    0.010118  -0.085884      -0.003700
#
#                    Property_Area  Loan_Status
# ApplicantIncome        -0.009500    -0.004710
# CoapplicantIncome       0.028111    -0.089189
# LoanAmount             -0.044776    -0.036416
# Loan_Amount_Term       -0.077620    -0.020974
# Credit_History          0.001963     0.540556
# Loan_ID                -0.155416     0.011773
# Gender                 -0.025752     0.017987
# Married                 0.004257     0.091478
# Dependents             -0.000244     0.010118
# Education              -0.065243    -0.085884
# Self_Employed          -0.030860    -0.003700
# Property_Area           1.000000     0.032112
# Loan_Status             0.032112     1.000000

# %%
#visualize correlation b/w features and target variables
plt.figure(figsize=(22,7))
df1.corr()['Loan_Status'].sort_values(ascending=False).drop(['Loan_Status']).plot(kind='bar',color='c')
plt.xlabel('feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#using heatmap to visualization correlation b/w features and target variables
#heat map
fig, ax = plt.subplots(figsize=(17,13))
sns.heatmap(df1.corr(),cmap = 'rainbow', annot=True, linewidths=.5, ax=ax)
plt.show()

# %% [markdown]
# drop loan_id column we dont need that because of it shows same as inex id

# %%
df1 = df1.drop(columns = ['Loan_ID'],axis = 1)
#splitting target and variables
X = df1.drop(columns = ['Loan_Status'],axis = 1)
y = df1['Loan_Status']

# %%
X.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849        1621.245798  146.412162             360.0
# 1             4583        1508.000000  128.000000             360.0
# 2             3000        1621.245798   66.000000             360.0
# 3             2583        2358.000000  120.000000             360.0
# 4             6000        1621.245798  141.000000             360.0
#
#    Credit_History  Gender  Married  Dependents  Education  Self_Employed  \
# 0             1.0       1        0           0          0              0
# 1             1.0       1        1           1          0              0
# 2             1.0       1        1           0          0              1
# 3             1.0       1        1           0          1              0
# 4             1.0       1        0           0          0              0
#
#    Property_Area
# 0              2
# 1              0
# 2              2
# 3              2
# 4              2

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x= pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %%
x.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0         0.072991          -0.275207    0.000000          0.279851
# 1        -0.134412          -0.318442   -0.219273          0.279851
# 2        -0.393747          -0.275207   -0.957641          0.279851
# 3        -0.462062           0.006073   -0.314547          0.279851
# 4         0.097728          -0.275207   -0.064454          0.279851
#
#    Credit_History    Gender   Married  Dependents  Education  Self_Employed  \
# 0        0.411733  0.472343 -1.372089   -0.737806  -0.528362      -0.392601
# 1        0.411733  0.472343  0.728816    0.253470  -0.528362      -0.392601
# 2        0.411733  0.472343  0.728816   -0.737806  -0.528362       2.547117
# 3        0.411733  0.472343  0.728816   -0.737806   1.892641      -0.392601
# 4        0.411733  0.472343 -1.372089   -0.737806  -0.528362      -0.392601
#
#    Property_Area
# 0       1.223298
# 1      -1.318513
# 2       1.223298
# 3       1.223298
# 4       1.223298

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 614, dtype: int32

# %%
y.value_counts()
# Out:
# 1    422
# 0    192
# Name: Loan_Status, dtype: int64

# %%
#let’s visualize the count of target variable using Seaborn
sns.countplot(df1['Loan_Status'])
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %% [markdown]
# We can see that classes are imbalanced and we use SMOTE() technique to balance the imbalanced dataset,

# %%
#convert imbalanced data into balance data
from imblearn.over_sampling import SMOTE
SM = SMOTE()
x , y = SM.fit_resample(x,y)

# %%
#checking balanced data
sns.countplot(y)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %%
y.value_counts()
# Out:
# 0    422
# 1    422
# Name: Loan_Status, dtype: int64

# %% [markdown]
# # Model Building

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,classification_report
import scikitplot as skplt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score,roc_curve

# %%
#split train test data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.25, random_state=50)

# %%
#Train result
KNN = KNeighborsClassifier()
KNN.fit(x_train, y_train)
y_pred =KNN .predict(x_train)
accuracy = classification_report(y_train, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_train, y_pred))


#Test result
KNN = KNeighborsClassifier()
KNN.fit(x_train, y_train)
y_pred =KNN .predict(x_test)
accuracy = classification_report(y_test, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84       316
#            1       0.82      0.88      0.85       317
#
#     accuracy                           0.85       633
#    macro avg       0.85      0.85      0.85       633
# weighted avg       0.85      0.85      0.85       633
#
# AxesSubplot(0.125,0.125;0.62x0.755)
#               precision    recall  f1-score   support
#
#            0       0.73      0.75      0.74       106
#            1       0.74      0.72      0.73       105
#
#     accuracy                           0.73       211
#    macro avg       0.73      0.73      0.73       211
# weighted avg       0.73      0.73      0.73       211
#
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
print("Training accuracy::",KNN.score(x_train,y_train))
print("Test accuracy::",KNN.score(x_test,y_test))
# Out:
# Training accuracy:: 0.8451816745655608
# Test accuracy:: 0.7345971563981043

# %%
print(cross_val_score(KNN,x,y,cv=5).mean())
# Out:
# 0.734636517328825

# %%
#roc_curve plot to check the socre of knn
fpr, tpr, _= roc_curve(y_test, y_pred)
auc_score = roc_auc_score(y_test, y_pred)
plt.plot(fpr, tpr, label="auc="+str(auc_score))
plt.box(True)
plt.title('ROC CURVE KNN')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)
plt.grid(True)
plt.show()
print('The Score for the ROC AUC Curve is : {}%'.format(round(auc_score,4)*100))
# Out:
# The Score for the ROC AUC Curve is : 73.45%

# %%
#train result
RFC = RandomForestClassifier()
RFC.fit(x_train, y_train)
y_pred =RFC .predict(x_train)
accuracy = classification_report(y_train, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_train, y_pred))


#test result
RFC = RandomForestClassifier()
RFC.fit(x_train, y_train)
y_pred =RFC .predict(x_test)
accuracy = classification_report(y_test, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       316
#            1       1.00      1.00      1.00       317
#
#     accuracy                           1.00       633
#    macro avg       1.00      1.00      1.00       633
# weighted avg       1.00      1.00      1.00       633
#
# AxesSubplot(0.125,0.125;0.62x0.755)
#               precision    recall  f1-score   support
#
#            0       0.90      0.75      0.82       106
#            1       0.79      0.91      0.85       105
#
#     accuracy                           0.83       211
#    macro avg       0.84      0.83      0.83       211
# weighted avg       0.84      0.83      0.83       211
#
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
print("Training accuracy::",RFC.score(x_train,y_train))
print("Test accuracy::",RFC.score(x_test,y_test))
# Out:
# Training accuracy:: 1.0
# Test accuracy:: 0.8341232227488151

# %%
print(cross_val_score(RFC,x,y,cv=5).mean())
# Out:
# 0.82828965905889

# %%
#roc_curve plot to check the socre of RFC
fpr, tpr, _= roc_curve(y_test, y_pred)
auc_score = roc_auc_score(y_test, y_pred)
plt.plot(fpr, tpr, label="auc="+str(auc_score))
plt.box(True)
plt.title('ROC CURVE RFC')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)
plt.grid(True)
plt.show()
print('The Score for the ROC Curve is : {}%'.format(round(auc_score,4)*100))
# Out:
# The Score for the ROC Curve is : 83.45%

# %%
#train result
DecisionTree = DecisionTreeClassifier()
DecisionTree.fit(x_train, y_train)
y_pred =DecisionTree .predict(x_train)
accuracy = classification_report(y_train, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_train, y_pred))

#test result
DecisionTree = DecisionTreeClassifier()
DecisionTree.fit(x_train, y_train)
y_pred =DecisionTree .predict(x_test)
accuracy = classification_report(y_test, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       316
#            1       1.00      1.00      1.00       317
#
#     accuracy                           1.00       633
#    macro avg       1.00      1.00      1.00       633
# weighted avg       1.00      1.00      1.00       633
#
# AxesSubplot(0.125,0.125;0.62x0.755)
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.77       106
#            1       0.77      0.75      0.76       105
#
#     accuracy                           0.76       211
#    macro avg       0.76      0.76      0.76       211
# weighted avg       0.76      0.76      0.76       211
#
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
print("Training accuracy::",DecisionTree.score(x_train,y_train))
print("Test accuracy::",DecisionTree.score(x_test,y_test))
# Out:
# Training accuracy:: 1.0
# Test accuracy:: 0.7630331753554502

# %%
print(cross_val_score(DecisionTree,x,y,cv=5).mean())
# Out:
# 0.7310721329952099

# %%
#roc_curve plot to check the socre of Decisiontree
fpr, tpr, _= roc_curve(y_test, y_pred)
auc_score = roc_auc_score(y_test, y_pred)
plt.plot(fpr, tpr, label="auc="+str(auc_score))
plt.box(True)
plt.title('ROC CURVE DecisionTree')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)
plt.grid(True)
plt.show()
print('The Score for the ROC Curve is : {}%'.format(round(auc_score,4)*100))
# Out:
# The Score for the ROC Curve is : 76.3%

# %% [markdown]
# # ENSEMBLE TECHNIQUES

# %%
#train result
adb = AdaBoostClassifier()
adb.fit(x_train, y_train)
y_pred =adb .predict(x_train)
accuracy = classification_report(y_train, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_train, y_pred))


#test result
adb = AdaBoostClassifier()
adb.fit(x_train, y_train)
y_pred =adb .predict(x_test)
accuracy = classification_report(y_test, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.74      0.81       316
#            1       0.78      0.90      0.83       317
#
#     accuracy                           0.82       633
#    macro avg       0.83      0.82      0.82       633
# weighted avg       0.83      0.82      0.82       633
#
# AxesSubplot(0.125,0.125;0.62x0.755)
#               precision    recall  f1-score   support
#
#            0       0.84      0.65      0.73       106
#            1       0.71      0.88      0.79       105
#
#     accuracy                           0.76       211
#    macro avg       0.78      0.76      0.76       211
# weighted avg       0.78      0.76      0.76       211
#
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
print("Training accuracy::",adb.score(x_train,y_train))
print("Test accuracy::",adb.score(x_test,y_test))
# Out:
# Training accuracy:: 0.8214849921011058
# Test accuracy:: 0.7630331753554502

# %%
print(cross_val_score(adb,x,y,cv=5).mean())
# Out:
# 0.7559594251901943

# %%
#roc_curve plot to check the socre of AdaBoostClassifier
fpr, tpr, _= roc_curve(y_test, y_pred)
auc_score = roc_auc_score(y_test, y_pred)
plt.plot(fpr, tpr, label="auc="+str(auc_score))
plt.box(True)
plt.title('ROC CURVE adb')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)
plt.grid(True)
plt.show()
print('The Score for the ROC Curve is : {}%'.format(round(auc_score,4)*100))
# Out:
# The Score for the ROC Curve is : 76.36%

# %%
#train result
gbc = GradientBoostingClassifier()
gbc.fit(x_train, y_train)
y_pred =gbc .predict(x_train)
accuracy = classification_report(y_train, y_pred)
print(accuracy)
print( skplt.metrics.plot_confusion_matrix(y_train, y_pred))


#test result
gbc = GradientBoostingClassifier()
gbc.fit(x_train, y_train)
y_pred =gbc .predict(x_test)
accuracy = classification_report(y_test, y_pred)
print(accuracy)
print( skplt.metrics.plot_confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.84      0.90       316
#            1       0.86      0.97      0.91       317
#
#     accuracy                           0.91       633
#    macro avg       0.91      0.91      0.91       633
# weighted avg       0.91      0.91      0.91       633
#
# AxesSubplot(0.125,0.125;0.62x0.755)
#               precision    recall  f1-score   support
#
#            0       0.86      0.70      0.77       106
#            1       0.74      0.89      0.81       105
#
#     accuracy                           0.79       211
#    macro avg       0.80      0.79      0.79       211
# weighted avg       0.80      0.79      0.79       211
#
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
print("Training accuracy::",gbc.score(x_train,y_train))
print("Test accuracy::",gbc.score(x_test,y_test))
# Out:
# Training accuracy:: 0.9067930489731437
# Test accuracy:: 0.7914691943127962

# %%
print(cross_val_score(gbc,x,y,cv=5).mean())
# Out:
# 0.79392786700479

# %%
#roc_curve plot to check the socre of GradientBoostClassifier
fpr, tpr, _= roc_curve(y_test, y_pred)
auc_score = roc_auc_score(y_test, y_pred)
plt.plot(fpr, tpr, label="auc="+str(auc_score))
plt.box(True)
plt.title('ROC CURVE gbc')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)
plt.grid(True)
plt.show()
print('The Score for the ROC Curve is : {}%'.format(round(auc_score,4)*100))
# Out:
# The Score for the ROC Curve is : 79.19%

# %% [markdown]
# inding the difference of F1 Score accuracy and cross validation score accuracy and the random forest model is having less difference is considered as best model and applying Hyper parameter tuning to increase the accuracy of that model.

# %% [markdown]
# # HyperParametr Tuning

# %%
 params = {'bootstrap': [True],
           'max_depth': [80, 90, 100, 110],
           'max_features': ['auto', 'sqrt', 'log2'],
           'min_samples_leaf': [3, 4, 5],
           'min_samples_split': [8, 10, 12],
           'n_estimators': [100,120,200,300]
}

# %%
model=RandomForestClassifier()

# %%
grid_clf=GridSearchCV(model,params,verbose=4,refit=True,n_jobs = -1)

# %%
grid_clf.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# GridSearchCV(estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True], 'max_depth': [80, 90, 100, 110],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [3, 4, 5],
#                          'min_samples_split': [8, 10, 12],
#                          'n_estimators': [100, 120, 200, 300]},
#              verbose=4)

# %%
final_model=grid_clf.best_estimator_
print(final_model)
# Out:
# RandomForestClassifier(max_depth=80, max_features='sqrt', min_samples_leaf=3,
#                        min_samples_split=8, n_estimators=200)

# %%
final_model=grid_clf.best_params_
print(final_model)
# Out:
# {'bootstrap': True, 'max_depth': 80, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 200}

# %%
final_model=grid_clf.best_score_
print(final_model)
# Out:
# 0.7930633670791151

# %%
final_model = RandomForestClassifier(n_estimators=20 , max_features = 'sqrt', max_depth = 80,
                                     bootstrap = True,min_samples_split = 8,min_samples_leaf = 3)                              
final_model.fit(x_train,y_train)
final_model.score(x_test,y_test)
# Out:
# 0.8056872037914692

# %%
y_pred=final_model.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8056872037914692

# %%
skplt.metrics.plot_confusion_matrix(y_test,y_pred)
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted label', ylabel='True label'>

# %%
print(cross_val_score(final_model,x,y,cv=5).mean())
# Out:
# 0.7915539588616513

# %%
#roc_curve plot to check the socre of RFC
fpr, tpr, _= roc_curve(y_test, y_pred)
auc_score = roc_auc_score(y_test, y_pred)
plt.plot(fpr, tpr, label="auc="+str(auc_score))
plt.box(True)
plt.title('ROC CURVE RFC')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)
plt.grid(True)
plt.show()
print('The Score for the ROC Curve is : {}%'.format(round(auc_score,4)*100))
# Out:
# The Score for the ROC Curve is : 80.60000000000001%

# %% [markdown]
# After hyper parameter our final model is 81% accuracy

# %%
import joblib
joblib.dump(final_model,"Loan_Prediction")
# Out:
# ['Loan_Prediction']
